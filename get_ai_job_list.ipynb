# %%
# pip install openpyxl
# pip install pandas
# pip install bs4

# %%
import pandas as pd
import openpyxl
from bs4 import BeautifulSoup

# %%
file_path = 'a_tag_list.xlsx'
output_filename = "ai_jobs_captured_list_2025-08-25.xlsx"

# %%
df = pd.read_excel(file_path)
# 전문(전체 내용)을 출력하려면 to_string()을 사용하세요.
print(df.head(1).to_string())
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0  <a target="_blank" class="flex flex-[1_0_0] items-center gap-2 rounded-[24px] border border-[#EDEDED] mx-4 h-[120px] shadow-[0px_4px_30px_0px_#00000008] transition-shadow hover:shadow-[0px_6px_16px_rgba(0,0,0,0.08)] md:mx-0 md:h-[164px] md:pl-[20px]" href="https://zighang.com/recruitment/074d5010-7b30-48fe-9d76-5da6d6ceca16" style="cursor: crosshair;"><div class="flex flex-1 flex-row items-center gap-2.5 md:gap-6" style="cursor: crosshair;"><section class="relative flex aspect-[1/1] flex-shrink-0 items-center justify-center rounded-xl md:rounded-2xl ml-2 w-[60px] md:ml-0 md:w-[80px]" style="background-color: rgb(78, 192, 108); cursor: crosshair;"><span class="font-bold text-white text-[11px] md:text-base whitespace-pre-line text-center leading-[14px] md:leading-[18px]" style="cursor: crosshair;" listly-xywh="710.9166870117188,415,44.16666793823242,36">LGAI연구원</span></section><div class="flex flex-col gap-[6px] md:gap-3" style="cursor: crosshair;"><div class="flex flex-wrap items-center gap-[0px] text-[#71717A] ds-web-summary" style="cursor: crosshair;"><span style="cursor: crosshair;" listly-xywh="797,371,78.45833587646484,22">LGAI연구원</span><span style="cursor: crosshair;"></span><span class="ml-2.5" style="cursor: crosshair;"></span></div><div class="flex items-center gap-2 text-wrap break-all font-bold text-black opacity-40" style="cursor: crosshair;"><p class="max-w-[240px] md:max-w-[356px] ds-web-title2" style="line-height: 140%; cursor: crosshair;" listly-xywh="797,405,356,56">Software Engineer Internship (Business Intelligence AI)</p></div><div class="flex flex-col gap-1 text-[12px] text-[#71717A] md:text-sm" style="cursor: crosshair;"><div class="flex flex-wrap items-center gap-[1px] md:gap-1 ds-web-summary" style="cursor: crosshair;"><span style="cursor: crosshair;" listly-xywh="797,473,63.364585876464844,22">경력 무관</span><span style="cursor: crosshair;" listly-xywh="864.3646240234375,473,4.7916669845581055,22">·</span><span style="cursor: crosshair;" listly-xywh="873.15625,473,78.08333587646484,22">체험형 인턴</span><span style="cursor: crosshair;" listly-xywh="955.2396240234375,473,4.7916669845581055,22">·</span><span style="cursor: crosshair;" listly-xywh="964.03125,473,58.895835876464844,22">학사석사</span><span style="cursor: crosshair;" listly-xywh="1026.9271240234375,473,4.7916669845581055,22">·</span><span style="cursor: crosshair;"><div class="text-8px flex w-full items-center justify-start text-[#71717A]" style="cursor: crosshair;"><span class="break-keep" style="cursor: crosshair;" listly-xywh="1035.71875,473,29.447917938232422,22">서울</span></div></span><span style="cursor: crosshair;"><div data-orientation="vertical" role="none" class="shrink-0 ml-2 mr-0 h-4 w-[1px] bg-line" style="cursor: crosshair;"></div></span><span style="cursor: crosshair;"><div class="mx-0 flex gap-0 text-[15px] text-[#71717A] md:mx-2" style="cursor: crosshair;"><img alt="조회수 아이콘" loading="lazy" width="0" height="0" decoding="async" data-nimg="1" class="h-[14px] w-[14px] flex-shrink-0 md:h-[20px] md:w-[20px]" src="https://zighang.com/icon/visibility.svg" style="color: transparent; cursor: crosshair;" listly-xywh="1090.166748046875,473,20,20"><div class="mx-[1px] flex items-center text-[11px] md:mx-[4px] md:text-[16px] " style="cursor: crosshair;" listly-xywh="1114.166748046875,473,36.489585876464844,22">1417</div></div></span></div></div></div></div><div class="flex h-full flex-row items-center justify-center border-l border-[#EDEDED] pl-0" style="width: 84px; cursor: crosshair;"><div class="flex h-full w-full flex-col" style="cursor: crosshair;"><div class="flex h-1/2 cursor-pointer items-center justify-center " style="border-top-right-radius: 20px; cursor: crosshair;"><button class="text-40px flex h-9 w-9 items-center justify-center p-1 md:h-12 md:w-12 " style="cursor: crosshair;"><img alt="북마크 border 아이콘" loading="lazy" width="0" height="0" decoding="async" data-nimg="1" class="h-5 w-5 md:h-7 md:w-7" src="https://zighang.com/icon/bookmar ...

# %%
html = df.iloc[:1, 0]
# print('html : ', html)
count = 1
for snippet in html:
    # print('snippet', count, ': '+ snippet)
    soup = BeautifulSoup(snippet, "html.parser")
    # print(soup.get_text())
    job_info = {
        "회사": "N/A",
        "제목": "N/A",
        "경력": "N/A",
        "근무형태": "N/A",
        "학력": "N/A",
        "근무지역": "N/A",
        "링크": "N/A",
    }
    link_tag = soup.find('a', href=True)
    
    if link_tag: # 링크 태그가 존재하는 경우
        job_info["링크"] = link_tag['href']
        
    company_tag = soup.select_one('div section span')
    # print('company_tag:', company_tag)
    if company_tag:
        job_info["회사"] = company_tag.get_text(strip=True)
    
    title_tag = soup.select_one('div div p')
    if title_tag: 
        job_info["제목"] = title_tag.get_text(strip=True)
    
    other_containers = soup.select_one('div.ds-web-summary:last-of-type')
    if other_containers:
        items = other_containers.find_all(recursive=False)
        others = []
        for item in items:
            # print(item)
            if item.name == 'span':
                text = item.get_text(strip=True)
                if text and text != "·":
                    # print(text)
                    others.append(text)
        if len(others) > 0:
            # print(others)
            job_info['경력'] = others[0]
            job_info['근무형태'] = others[1]
            job_info['학력'] = others[2]
            job_info['근무지역'] = others[3]
            # print(job_info)
# Out:
# html :  0    <a target="_blank" class="flex flex-[1_0_0] it...
# Name: LABEL-1, dtype: object
# snippet 1 : <a target="_blank" class="flex flex-[1_0_0] items-center gap-2 rounded-[24px] border border-[#EDEDED] mx-4 h-[120px] shadow-[0px_4px_30px_0px_#00000008] transition-shadow hover:shadow-[0px_6px_16px_rgba(0,0,0,0.08)] md:mx-0 md:h-[164px] md:pl-[20px]" href="https://zighang.com/recruitment/074d5010-7b30-48fe-9d76-5da6d6ceca16" style="cursor: crosshair;"><div class="flex flex-1 flex-row items-center gap-2.5 md:gap-6" style="cursor: crosshair;"><section class="relative flex aspect-[1/1] flex-shrink-0 items-center justify-center rounded-xl md:rounded-2xl ml-2 w-[60px] md:ml-0 md:w-[80px]" style="background-color: rgb(78, 192, 108); cursor: crosshair;"><span class="font-bold text-white text-[11px] md:text-base whitespace-pre-line text-center leading-[14px] md:leading-[18px]" style="cursor: crosshair;" listly-xywh="710.9166870117188,415,44.16666793823242,36">LGAI연구원</span></section><div class="flex flex-col gap-[6px] md:gap-3" style="cursor: crosshair;"><div class="flex flex-wrap items-center gap-[0px] text-[#71717A] ds-web-summary" style="cursor: crosshair;"><span style="cursor: crosshair;" listly-xywh="797,371,78.45833587646484,22">LGAI연구원</span><span style="cursor: crosshair;"></span><span class="ml-2.5" style="cursor: crosshair;"></span></div><div class="flex items-center gap-2 text-wrap break-all font-bold text-black opacity-40" style="cursor: crosshair;"><p class="max-w-[240px] md:max-w-[356px] ds-web-title2" style="line-height: 140%; cursor: crosshair;" listly-xywh="797,405,356,56">Software Engineer Internship (Business Intelligence AI)</p></div><div class="flex flex-col gap-1 text-[12px] text-[#71717A] md:text-sm" style="cursor: crosshair;"><div class="flex flex-wrap items-center gap-[1px] md:gap-1 ds-web-summary" style="cursor: crosshair;"><span style="cursor: crosshair;" listly-xywh="797,473,63.364585876464844,22">경력 무관</span><span style="cursor: crosshair;" listly-xywh="864.3646240234375,473,4.7916669845581055,22">·</span><span style="cursor: crosshair;" listly-xywh="873.15625,473,78.08333587646484,22">체험형 인턴</span><span style="cursor: crosshair;" listly-xywh="955.2396240234375,473,4.7916669845581055,22">·</span><span style="cursor: crosshair;" listly-xywh="964.03125,473,58.895835876464844,22">학사석사</span><span style="cursor: crosshair;" listly-xywh="1026.9271240234375,473,4.7916669845581055,22">·</span><span style="cursor: crosshair;"><div class="text-8px flex w-full items-center justify-start text-[#71717A]" style="cursor: crosshair;"><span class="break-keep" style="cursor: crosshair;" listly-xywh="1035.71875,473,29.447917938232422,22">서울</span></div></span><span style="cursor: crosshair;"><div data-orientation="vertical" role="none" class="shrink-0 ml-2 mr-0 h-4 w-[1px] bg-line" style="cursor: crosshair;"></div></span><span style="cursor: crosshair;"><div class="mx-0 flex gap-0 text-[15px] text-[#71717A] md:mx-2" style="cursor: crosshair;"><img alt="조회수 아이콘" loading="lazy" width="0" height="0" decoding="async" data-nimg="1" class="h-[14px] w-[14px] flex-shrink-0 md:h-[20px] md:w-[20px]" src="https://zighang.com/icon/visibility.svg" style="color: transparent; cursor: crosshair;" listly-xywh="1090.166748046875,473,20,20"><div class="mx-[1px] flex items-center text-[11px] md:mx-[4px] md:text-[16px] " style="cursor: crosshair;" listly-xywh="1114.166748046875,473,36.489585876464844,22">1417</div></div></span></div></div></div></div><div class="flex h-full flex-row items-center justify-center border-l border-[#EDEDED] pl-0" style="width: 84px; cursor: crosshair;"><div class="flex h-full w-full flex-col" style="cursor: crosshair;"><div class="flex h-1/2 cursor-pointer items-center justify-center " style="border-top-right-radius: 20px; cursor: crosshair;"><button class="text-40px flex h-9 w-9 items-center justify-center p-1 md:h-12 md:w-12 " style="cursor: crosshair;"><img alt="북마크 border 아이콘" loading="lazy" width="0" height="0" decoding="async" data-nimg="1" class="h-5 w-5 md:h-7 md:w-7" src="https://zighang.com/ico ...

# %%
html = df.iloc[:1, 0]
job_info=get_job_info(html)
print(job_info)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 html = df.iloc[:, 0]
# ----> 2 job_info=get_job_info(html)
#       3 print(job_info)
#
# Cell In[7], line 2, in get_job_info(html)
#       1 def get_job_info(html):
# ----> 2     soup = BeautifulSoup(html, "html.parser")
#       3     job_info = {
#       4         "회사": "N/A",
#       5         "제목": "N/A",
#    (...)     10         "링크": "N/A",
#      11     }
#      12     link_tag = soup.find('a', href=True)
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\bs4\__init__.py:470, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     463 rejections = []
#     464 success = False
#     465 for (
#     466     self.markup,
#     467     self.original_encoding,
#     468     self.declared_html_encoding,
#     469     self.contains_replacement_characters,
# --> 470 ) in self.builder.prepare_markup(
#     471     markup, from_encoding, exclude_encodings=exclude_encodings
#     472 ):
#     473     self.reset()
#     474     self.builder.initialize_soup(self)
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\bs4\builder\_htmlparser.py:423, in HTMLParserTreeBuilder.prepare_markup(self, markup, user_specified_encoding, document_declared_encoding, exclude_encodings)
#     418 if document_declared_encoding:
#     419     # This was found in the document; treat it as a slightly
#     420     # lower-priority user encoding.
#     421     user_encodings.append(document_declared_encoding)
# --> 423 dammit = UnicodeDammit(
#     424     markup,
#     425     known_definite_encodings=known_definite_encodings,
#     426     user_encodings=user_encodings,
#     427     is_html=True,
#     428     exclude_encodings=exclude_encodings,
#     429 )
#     431 if dammit.unicode_markup is None:
#     432     # In every case I've seen, Unicode, Dammit is able to
#     433     # convert the markup into Unicode, even if it needs to use
#    (...)    436     # HTMLParser can only parse Unicode, so here we handle
#     437     # that code path.
#     438     raise ParserRejectedMarkup(
#     439         "Could not convert input to Unicode, and html.parser will not accept bytestrings."
#     440     )
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\bs4\dammit.py:790, in UnicodeDammit.__init__(self, markup, known_definite_encodings, smart_quotes_to, is_html, exclude_encodings, user_encodings, override_encodings)
#     788 self.is_html = is_html
#     789 self.log = getLogger(__name__)
# --> 790 self.detector = EncodingDetector(
#     791     markup,
#     792     known_definite_encodings,
#     793     is_html,
#     794     exclude_encodings,
#     795     user_encodings,
#     796     override_encodings,
#     797 )
#     799 # Short-circuit if the data is in Unicode to begin with.
#     800 if isinstance(markup, str):
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\bs4\dammit.py:565, in EncodingDetector.__init__(self, markup, known_definite_encodings, is_html, exclude_encodings, user_encodings, override_encodings)
#     562 self.declared_encoding: Optional[str] = None
#     564 # First order of business: strip a byte-order mark.
# --> 565 self.markup, self.sniffed_encoding = self.strip_byte_order_mark(markup)
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\bs4\dammit.py:660, in EncodingDetector.strip_byte_order_mark(cls, data)
#     655 if isinstance(data, str):
#     656     # Unicode data cannot have a byte-order mark.
#     657     return data, encoding
#     658 if (
#     659     (len(data) >= 4)
# --> 660     and (data[:2] == b"\xfe\xff")
#     661     and (data[2:4] != b"\x00\x00")
#     662 ):
#     663     encoding = "utf-16be"
#     664     data = data[2:]
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:1577, in NDFrame.__nonzero__(self)
#    1575 @final
#    1576 def __nonzero__(self) -> NoReturn:
# -> 1577     raise ValueError(
#    1578         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
htmls = df.iloc[:, 0]
# extracted_data = []
print(htmls[0])
# Out:
# <a target="_blank" class="flex flex-[1_0_0] items-center gap-2 rounded-[24px] border border-[#EDEDED] mx-4 h-[120px] shadow-[0px_4px_30px_0px_#00000008] transition-shadow hover:shadow-[0px_6px_16px_rgba(0,0,0,0.08)] md:mx-0 md:h-[164px] md:pl-[20px]" href="https://zighang.com/recruitment/074d5010-7b30-48fe-9d76-5da6d6ceca16" style="cursor: crosshair;"><div class="flex flex-1 flex-row items-center gap-2.5 md:gap-6" style="cursor: crosshair;"><section class="relative flex aspect-[1/1] flex-shrink-0 items-center justify-center rounded-xl md:rounded-2xl ml-2 w-[60px] md:ml-0 md:w-[80px]" style="background-color: rgb(78, 192, 108); cursor: crosshair;"><span class="font-bold text-white text-[11px] md:text-base whitespace-pre-line text-center leading-[14px] md:leading-[18px]" style="cursor: crosshair;" listly-xywh="710.9166870117188,415,44.16666793823242,36">LGAI연구원</span></section><div class="flex flex-col gap-[6px] md:gap-3" style="cursor: crosshair;"><div class="flex flex-wrap items-center gap-[0px] text-[#71717A] ds-web-summary" style="cursor: crosshair;"><span style="cursor: crosshair;" listly-xywh="797,371,78.45833587646484,22">LGAI연구원</span><span style="cursor: crosshair;"></span><span class="ml-2.5" style="cursor: crosshair;"></span></div><div class="flex items-center gap-2 text-wrap break-all font-bold text-black opacity-40" style="cursor: crosshair;"><p class="max-w-[240px] md:max-w-[356px] ds-web-title2" style="line-height: 140%; cursor: crosshair;" listly-xywh="797,405,356,56">Software Engineer Internship (Business Intelligence AI)</p></div><div class="flex flex-col gap-1 text-[12px] text-[#71717A] md:text-sm" style="cursor: crosshair;"><div class="flex flex-wrap items-center gap-[1px] md:gap-1 ds-web-summary" style="cursor: crosshair;"><span style="cursor: crosshair;" listly-xywh="797,473,63.364585876464844,22">경력 무관</span><span style="cursor: crosshair;" listly-xywh="864.3646240234375,473,4.7916669845581055,22">·</span><span style="cursor: crosshair;" listly-xywh="873.15625,473,78.08333587646484,22">체험형 인턴</span><span style="cursor: crosshair;" listly-xywh="955.2396240234375,473,4.7916669845581055,22">·</span><span style="cursor: crosshair;" listly-xywh="964.03125,473,58.895835876464844,22">학사석사</span><span style="cursor: crosshair;" listly-xywh="1026.9271240234375,473,4.7916669845581055,22">·</span><span style="cursor: crosshair;"><div class="text-8px flex w-full items-center justify-start text-[#71717A]" style="cursor: crosshair;"><span class="break-keep" style="cursor: crosshair;" listly-xywh="1035.71875,473,29.447917938232422,22">서울</span></div></span><span style="cursor: crosshair;"><div data-orientation="vertical" role="none" class="shrink-0 ml-2 mr-0 h-4 w-[1px] bg-line" style="cursor: crosshair;"></div></span><span style="cursor: crosshair;"><div class="mx-0 flex gap-0 text-[15px] text-[#71717A] md:mx-2" style="cursor: crosshair;"><img alt="조회수 아이콘" loading="lazy" width="0" height="0" decoding="async" data-nimg="1" class="h-[14px] w-[14px] flex-shrink-0 md:h-[20px] md:w-[20px]" src="https://zighang.com/icon/visibility.svg" style="color: transparent; cursor: crosshair;" listly-xywh="1090.166748046875,473,20,20"><div class="mx-[1px] flex items-center text-[11px] md:mx-[4px] md:text-[16px] " style="cursor: crosshair;" listly-xywh="1114.166748046875,473,36.489585876464844,22">1417</div></div></span></div></div></div></div><div class="flex h-full flex-row items-center justify-center border-l border-[#EDEDED] pl-0" style="width: 84px; cursor: crosshair;"><div class="flex h-full w-full flex-col" style="cursor: crosshair;"><div class="flex h-1/2 cursor-pointer items-center justify-center " style="border-top-right-radius: 20px; cursor: crosshair;"><button class="text-40px flex h-9 w-9 items-center justify-center p-1 md:h-12 md:w-12 " style="cursor: crosshair;"><img alt="북마크 border 아이콘" loading="lazy" width="0" height="0" decoding="async" data-nimg="1" class="h-5 w-5 md:h-7 md:w-7" src="https://zighang.com/icon/bookmark_o ...

# %%
def get_job_info(html):
    soup = BeautifulSoup(html, "html.parser")
    job_info = {
        "회사": "N/A",
        "제목": "N/A",
        "경력": "N/A",
        "근무형태": "N/A",
        "학력": "N/A",
        "근무지역": "N/A",
        "링크": "N/A",
    }
    link_tag = soup.find('a', href=True)
    
    if link_tag: # 링크 태그가 존재하는 경우
        job_info["링크"] = link_tag['href']
        
    company_tag = soup.select_one('div section span')
    if company_tag:
        job_info["회사"] = company_tag.get_text(strip=True)
    else:
        company_container = soup.select_one('div.ds-web-summary')
        if company_container:
            company_tag = company_container.find('span')
            if company_tag:
                job_info["회사"] = company_tag.get_text(strip=True)
    
    title_tag = soup.select_one('div div p')
    if title_tag: 
        job_info["제목"] = title_tag.get_text(strip=True)
    
    other_containers = soup.select_one('div.ds-web-summary:last-of-type')
    if other_containers:
        items = other_containers.find_all(recursive=False)
        others = []
        for item in items:
            if item.name == 'span':
                text = item.get_text(strip=True)
                if text and text != "·":
                    others.append(text)
        if len(others) > 0:
            job_info['경력'] = others[0] if len(others) > 0 else "N/A"
            job_info['근무형태'] = others[1] if len(others) > 1 else "N/A"
            job_info['학력'] = others[2] if len(others) > 2 else "N/A"
            job_info['근무지역'] = others[3] if len(others) > 3 else "N/A"

    return job_info

# %%
htmls = df.iloc[:, 0]
extracted_data = []

for html in htmls:
    job_info = get_job_info(html)
    extracted_data.append(job_info)

print(extracted_data)
# Out:
# [{'회사': 'LGAI연구원', '제목': 'Software Engineer Internship (Business Intelligence AI)', '경력': '경력 무관', '근무형태': '체험형 인턴', '학력': '학사석사', '근무지역': '서울', '링크': 'https://zighang.com/recruitment/074d5010-7b30-48fe-9d76-5da6d6ceca16'}, {'회사': 'LGAI연구원', '제목': 'NLP Quality Engineering Internship', '경력': '경력 무관', '근무형태': '체험형 인턴', '학력': '학력 무관', '근무지역': '서울', '링크': 'https://zighang.com/recruitment/7bf7df09-7923-4aea-b70c-575ae11957f8'}, {'회사': '업스테이지', '제목': 'Al Agent Engineer 채용', '경력': '경력 무관', '근무형태': '전환형 인턴정규직', '학력': '학력 무관', '근무지역': '경기', '링크': 'https://zighang.com/recruitment/469a0e1b-f60c-4148-af16-94ab5733256b'}, {'회사': '업스테이지', '제목': 'Al Agentic Engineer 채용', '경력': '1년차 이상', '근무형태': '전환형 인턴정규직', '학력': '학력 무관', '근무지역': '경기', '링크': 'https://zighang.com/recruitment/6b4b7855-f21d-41fa-ade1-a615dfd81e12'}, {'회사': '업스테이지', '제목': 'AI Research Engineer - LLM Eval 인턴십 모집', '경력': '경력 무관', '근무형태': '전환형 인턴체험형 인턴', '학력': '학력 무관', '근무지역': '경기', '링크': 'https://zighang.com/recruitment/2c8e5066-d684-4eda-a6df-f50ee24d7bcb'}, {'회사': '업스테이지', '제목': '전문 연구 요원 신규 편입 & 전직 AI Agentic Engineer 채용', '경력': '경력 무관', '근무형태': '병역특례', '학력': '학력 무관', '근무지역': '경기', '링크': 'https://zighang.com/recruitment/3dbad478-78b0-4d2b-9701-7e14508e5d6e'}, {'회사': '업스테이지', '제목': 'AI Research Engineer - LLM Post-training 채용', '경력': '경력 무관', '근무형태': '정규직체험형 인턴', '학력': '학력 무관', '근무지역': '경기', '링크': 'https://zighang.com/recruitment/ff8a0ab9-56f1-444b-bcc0-7a6e65714cfb'}, {'회사': '업스테이지', '제목': 'AI Research Engineer - LLM', '경력': '경력 무관', '근무형태': '정규직체험형 인턴', '학력': '학력 무관', '근무지역': '경기', '링크': 'https://zighang.com/recruitment/320ff2d3-f2f8-48a0-8492-ddd4d8fd86a0'}, {'회사': 'ABLY', '제목': '머신 러닝 엔지니어 인턴', '경력': '신입~1년차', '근무형태': '전환형 인턴정규직', '학력': '학력 무관', '근무지역': '서울', '링크': 'https://zighang.com/recruitment/702a4c00-f7a7-4144-9d5e-9be154ec0603'}, {'회사': 'UpstageJapan', '제목': 'Solutions Architect - Japan', '경력': '1년차 이상', '근무형태': '정규직계약직', '학력': '학사', '근무지역': '기타', '링크': 'https://zighang.com/recruitment/3c173b84-c116-4fd4-a14d-6f9fc4cc774f'}, {'회사': '마이리얼트립', '제목': '데이터 엔지니어 채용', '경력': '1년차 이상', '근무형태': '정규직', '학력': '학력 무관', '근무지역': '기타', '링크': 'https://zighang.com/recruitment/902359bb-b0e8-4e62-8b39-5c8a53acdbc7'}, {'회사': '월드퀀트', '제목': 'BRAIN AI Researcher', '경력': '경력 무관', '근무형태': '정규직', '학력': '학사', '근무지역': '서울', '링크': 'https://zighang.com/recruitment/a5759939-1d5b-4144-b8e8-df194c1235a6'}, {'회사': '라인플러스', '제목': 'Applied Machine Learning Engineer 모집', '경력': '1년차 이상', '근무형태': '정규직', '학력': '학사', '근무지역': '기타', '링크': 'https://zighang.com/recruitment/6ae552a3-afab-453b-801e-f3f65aac14e6'}, {'회사': 'PTKOREA', '제목': 'AI 콘텐츠 최적화 툴 개발 _AI 개발 지원 인턴 채용', '경력': '경력 무관', '근무형태': '체험형 인턴', '학력': '학사', '근무지역': '서울', '링크': 'https://zighang.com/recruitment/25b6b7d6-e451-44f3-a974-5b1c16fe93eb'}, {'회사': '셀렉트스타', '제목': 'Al Engineer (계약직) 채용', '경력': '신입~1년차', '근무형태': '계약직', '학력': '학사', '근무지역': '서울', '링크': 'https://zighang.com/recruitment/8bc393aa-1011-42c5-8b80-c733c897d1be'}, {'회사': '셀렉트스타', '제목': '[ 경력 ] Data Manager', '경력': '경력 무관', '근무형태': '계약직정규직', '학력': '학력 무관', '근무지역': '기타', '링크': 'https://zighang.com/recruitment/9ebed284-d945-45bc-8d4c-36bfd4853ff2'}, {'회사': '미소', '제목': 'LLM Engineer (Senior)', '경력': '경력 무관', '근무형태': '정규직', '학력': '학력 무관', '근무지역': '서울', '링크': 'https://zighang.com/recruitment/bf4e8f3e-ed53-43f5-871c-eeabbed56fab'}, {'회사': 'LG AI연구원', '제목': 'Research Scientist - Large Multimodal Model', '경력': '경력 무관', '근무형태': '정규직', '학력': '학사', '근무지역': '기타', '링크': 'https://zighang.com/recruitment/60019c31-594d-4558-9406-6029592e3e02'}, {'회사': '뤼튼테크놀로지스', '제목': '[뤼튼] Service Manager 인턴', '경력': '경력 무관', '근무형태': '체험형 인턴', '학력': '학력 무관', '근무지역': '서울', '링크': 'https://zighang.com/recruitment/fed2b97d-1535-4333-bdf8-8dcfdb1b9657'}, {'회사': '뤼튼테크놀로지스', '제목': '[뤼튼] [AX팀] Agent Developer 인턴', '경력': '경력 무관', '근무형태': '계약직', '학력': '학력 무관', '근무지역': '서울', '링크': 'https://zighang.com/recruitment/4bd0cefc-dbe7-4c4a-8a13-c367f37a0066'}, {'회사': 'NC AI', '제목': '다국어 데이터 처리를 위한 언어공학자 및 개발자 채용 (일본어, 중국어)', '경력': '경력 무관', '근무 ...

# %%
if extracted_data:
    processed_df = pd.DataFrame(extracted_data)
    cols = [
        "회사",
        "제목",
        "경력",
        "근무형태",
        "학력",
        "근무지역",
        "링크"
    ]
    processed_df = processed_df[cols]
    # print(processed_df)
    # print(processed_df.info)
    processed_df.to_excel(output_filename, index=False)
    print(
        f"데이터 처리가 완료되었습니다. 결과는 '{output_filename}' 파일에 저장되었습니다."
    )
# Out:
# 데이터 처리가 완료되었습니다. 결과는 'ai_jobs_captured_list_2025-08-25.xlsx' 파일에 저장되었습니다.

# %%
print(processed_df.head().to_string())  # 데이터프레임의 상위 5개 행 출력
# Out:
#         회사                                                       제목      경력          근무형태     학력 근무지역                                                                    링크
# 0  LGAI연구원  Software Engineer Internship (Business Intelligence AI)   경력 무관        체험형 인턴   학사석사   서울  https://zighang.com/recruitment/074d5010-7b30-48fe-9d76-5da6d6ceca16
# 1  LGAI연구원                       NLP Quality Engineering Internship   경력 무관        체험형 인턴  학력 무관   서울  https://zighang.com/recruitment/7bf7df09-7923-4aea-b70c-575ae11957f8
# 2    업스테이지                                     Al Agent Engineer 채용   경력 무관     전환형 인턴정규직  학력 무관   경기  https://zighang.com/recruitment/469a0e1b-f60c-4148-af16-94ab5733256b
# 3    업스테이지                                   Al Agentic Engineer 채용  1년차 이상     전환형 인턴정규직  학력 무관   경기  https://zighang.com/recruitment/6b4b7855-f21d-41fa-ade1-a615dfd81e12
# 4    업스테이지                   AI Research Engineer - LLM Eval 인턴십 모집   경력 무관  전환형 인턴체험형 인턴  학력 무관   경기  https://zighang.com/recruitment/2c8e5066-d684-4eda-a6df-f50ee24d7bcb
