# %%
import pandas as pd
import requests
import json
import re
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup, Tag
from datetime import date
import time

# %%
today = date.today()
formatted_date = today.strftime("%Y-%m-%d")

input_filename = f'sheets/list_with_applyLink_{formatted_date}.xlsx'

df = pd.read_excel(input_filename)

# %%
def extract_main_content(html_source):
    """
    BeautifulSoup을 사용하여 HTML의 header와 footer 사이의 내용만 추출합니다.
    """
    original_soup = BeautifulSoup(html_source, "html.parser")

    header = original_soup.find("header")
    footer = original_soup.find("footer")

    # header와 footer 사이의 컨텐츠만 담을 리스트
    content_tags = []

    if header:
        for element in header.next_siblings:
            if element is footer:
                break
            # Tag 객체인 경우에만 추가 (NavigableString 같은 다른 타입 제외)
            if isinstance(element, Tag):
                content_tags.append(element)
    else:
        # header가 없으면 body 전체를 대상으로 하되, footer는 제거
        body_content = original_soup.find_all("body")
        if body_content:
            for element in body_content:
                if element is not footer:
                    content_tags.append(element)

    # 추출된 내용으로 새로운 soup 객체를 만들어 순수한 텍스트만 반환
    new_soup = BeautifulSoup("<body></body>", "html.parser")
    body = new_soup.body
    for tag in content_tags:
        body.append(tag)

    # 최종적으로 정제된 텍스트 반환
    return new_soup.get_text(separator=" ", strip=True)

# %%
API_URL = "http://localhost:11434/v1/chat/completions"
MODEL_NAME = "gpt-oss"

def call_local_llm(html_content):
    """
    로컬 LLM에 정제된 텍스트를 보내 자격요건과 우대사항을 추출합니다.
    """
    headers = {"Content-Type": "application/json"}

    prompt = f"""
    다음은 채용 공고 페이지의 내용입니다. 이 내용에서 '자격요건'과 '우대사항'을 찾아서 각각 정리하라.
    결과는 반드시 아래와 같은 JSON 형식으로만 응답하라. 만약 내용이 없다면 빈 리스트([])로 응답하라.

    {{
      "자격요건": [
        "자격요건1",
        "자격요건2",
        ....
      ],
      "우대사항": [
        "우대사항1",
        "우대사항2",
        ....
      ]
    }}

    --- 공고 내용 시작 ---
    {html_content}
    --- 공고 내용 끝 ---
    """

    data = {
        "model": MODEL_NAME,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.0,
    }

    try:
        response = requests.post(
            API_URL, headers=headers, data=json.dumps(data), timeout=300
        )
        response.raise_for_status()
        response_json = response.json()
        content_str = response_json["choices"][0]["message"]["content"]

        # JSON 블록을 추출하기 위한 정규 표현식
        # ```json ... ``` 또는 단순히 {...} 형태를 찾습니다.
        json_match = re.search(r"```json\s*(\{.*?\})\s*```", content_str, re.DOTALL)
        if json_match:
            json_str = json_match.group(1)
        else:
            # ```json ... ``` 형태가 아니면 전체 내용을 JSON으로 시도
            json_str = content_str.strip()

        parsed_content = json.loads(json_str)
        return parsed_content
    except requests.exceptions.RequestException as e:
        print(f"  -> LLM API 호출 오류: {e}")
        return None
    except (json.JSONDecodeError, KeyError, IndexError) as e:
        print(f"  -> LLM 응답 파싱 오류: {e}")
        print(f"  -> 받은 내용: {content_str[:300]}")  # 받은 내용 일부 출력
        return None

# %%
def main(df):
    # 1. 셀레니움 웹 드라이버 설정
    driver = webdriver.Chrome()
    results = []

    # 2. 각 링크를 순회하며 정보 추출
    for index, row in df.iterrows():

        apply_link = row["지원 링크"]
        print(f"처리 중 ({index + 1}/{len(df)}): {apply_link}")

        job_data = {
            "지원 링크": apply_link,  # 실제 링크 변수 사용
            "자격요건": "추출 실패",
            "우대사항": "추출 실패",
        }

        try:
            driver.get(apply_link)
            WebDriverWait(driver, 10).until(
                lambda d: d.execute_script("return document.readyState === 'complete'")
            )

            apply_page_html = driver.page_source

            # 메인 컨텐츠만 추출
            main_text = extract_main_content(apply_page_html)

            if not main_text.strip():
                print("  -> 처리할 텍스트 내용이 없습니다.")
                results.append(job_data)
                continue

            # LLM을 호출하여 정보 추출
            print(".....")
            extracted_info = call_local_llm(main_text)

            if extracted_info:
                job_data["자격요건"] = "\n".join(extracted_info.get("자격요건", []))
                job_data["우대사항"] = "\n".join(extracted_info.get("우대사항", []))
                print("  -> 정보 추출 완료.")
            else:
                print("  -> 정보 추출 실패.")

        except Exception as e:
            print(f"  -> 처리 중 오류 발생: {type(e).__name__} - {e}")
            # 오류 발생 시 다음 루프로 넘어감

        results.append(job_data)

    driver.quit()

    # 3. 결과 저장
    if results:
        result_df = pd.DataFrame(results)
        # "지원 링크"를 기준으로 원본과 결과 병합
        final_df = pd.merge(df, result_df, on="지원 링크", how="left")

        print(f"\n작업 완료!")
        return final_df
    else:
        print("\n처리된 결과가 없어 파일을 저장하지 않았습니다.")

# %%
start_time = time.time()  # 시작 시간 기록

result_df = main(df)

# output_filename = f'sheets/ai_jobs_final_results_{formatted_date}.xlsx'
# result_df.to_excel(output_filename, index=False)

end_time = time.time()  # 종료 시간 기록
elapsed = end_time - start_time
# print(f"\n최종 결과가 '{output_filename}' 파일에 저장되었습니다.")
print(f"\n최종 결과 산출 완료.")
print(f"총 소요 시간: {elapsed:.1f}초 ({elapsed/60:.1f}분)")
# Out:
# 처리 중 (1/113): https://jobs.careers.microsoft.com/global/en/job/1856383
# .....
#   -> 정보 추출 완료.
# 처리 중 (2/113): https://recruit.navercloudcorp.com/rcrt/view.do?annoId=30003735&lang=ko
# .....
#   -> 정보 추출 완료.
# 처리 중 (3/113): https://www.lgresearch.ai/careers/view?seq=250
# .....
#   -> 정보 추출 완료.
# 처리 중 (4/113): https://career.doosan.com/dsp/sa/RecList.jsp?REC_ID=1000353083&mode=goDetail
# .....
#   -> 정보 추출 완료.
# 처리 중 (5/113): https://recruit.navercloudcorp.com/rcrt/view.do?annoId=30003836&lang=ko
# .....
#   -> 정보 추출 완료.
# 처리 중 (6/113): https://www.lgresearch.ai/careers/view?seq=253
# .....
#   -> 정보 추출 완료.
# 처리 중 (7/113): https://career.doosan.com/dsp/sa/RecList.jsp?REC_ID=1000353021&mode=goDetail
# .....
#   -> 정보 추출 완료.
# 처리 중 (8/113): https://recruit.cj.net/recruit/ko/recruit/recruit/bestDetail.fo?zz_jo_num=J20250826034037
# .....
#   -> 정보 추출 완료.
# 처리 중 (9/113): https://careers.upstage.ai//o/ai-agent-engineer
# .....
#   -> 정보 추출 완료.
# 처리 중 (10/113): https://careers.upstage.ai/o/ai-agent-engineer
# .....
#   -> 정보 추출 완료.
# 처리 중 (11/113): https://careers.upstage.ai/o/ai-tech-data-management-internship
# .....
#   -> 정보 추출 완료.
# 처리 중 (12/113): https://careers.upstage.ai//o/ai-agentic-engineer-trp
# .....
#   -> 정보 추출 완료.
# 처리 중 (13/113): https://careers.upstage.ai//o/wbl-ai-research-engineer-llm-post-training
# .....
#   -> 정보 추출 완료.
# 처리 중 (14/113): https://careers.upstage.ai/o/wbl-ai-research-engineer-llm-post-training
# .....
#   -> 정보 추출 완료.
# 처리 중 (15/113): https://recruit.kreamcorp.com/rcrt/view.do?annoId=30003834&lang=ko
# .....
#   -> 정보 추출 완료.
# 처리 중 (16/113): https://careers.upstage.ai//o/upstage-japan-solutions-architect
# .....
#   -> 정보 추출 완료.
# 처리 중 (17/113): https://toss.im/career/job-detail?job_id=4100792003
# .....
#   -> 정보 추출 완료.
# 처리 중 (18/113): https://medtronic.wd1.myworkdayjobs.com/en-US/MedtronicCareers/job/Seoul-Seoul-Korea/Korea-Channel-Data-Analyst--Contract-_R37500?locationCountry=7a5a2aadf9d34086a2bfbfd408bc28da
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (19/113): https://tydtr0dj.ninehire.site/job_posting/CG6BujWw
# .....
#   -> 정보 추출 완료.
# 처리 중 (20/113): https://www.lgresearch.ai/careers/view?seq=249
# .....
#   -> 정보 추출 완료.
# 처리 중 (21/113): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (22/113): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (23/113): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (24/113): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (25/113): https://www.gsneotek.com/job_openings/?q=YToxOntzOjEyOiJrZXl3b3JkX3R5cGUiO3M6MzoiYWxsIjt9&bmode=view&idx=167354283&t=board//
# .....
#   -> 정보 추출 완료.
# 처리 중 (26/113): https://career.bagelcode.com/ko/o/123406
# .....
#   -> 정보 추출 완료.
# 처리 중 (27/113): https://koreainvestment-recruit.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (28/113): https://wrtn.career.greetinghr.com/ko/o/146983
# .....
#   -> 정보 추출 완료.
# 처리 중 (29/113): https://wrtn.career.greetinghr.com/ko/o/167455
# .....
#   -> 정보 추출 완료.
# 처리 중 (30/113): https://wrtn.career.greetinghr.com/ko/o/141628
# .....
#   -> 정보 추출 완료.
# 처리 중 (31/113): https://wrtn.career.greetinghr.com/ko/o/167936
# .....
#   -> 정보 추출 완료.
# 처리 중 (32/113): https://career.shiftup.co.kr/ko/o/168444
# .....
#   -> 정보 추출 완료.
# 처리 중 (33/113): https://wrtn.career.greetinghr.com/ko/o/101231
# .....
#   -> 정보 추출 완료.
# 처리 중 (34/113): https://wrtn.career.greetinghr.com/ko/o/161729
# .....
#   -> 정보 추출 완료.
# 처리 중 (35/113): https://nc-ai.career.greetinghr.com/ko/o/169509
# .....
#   -> 정보 추출 완료.
# 처리 중 (36/113): https://wrtn.career.greetinghr.com/ko/o/167444
# .....
#   -> 정보 추출 완료.
# 처리 중 (37/113): https://wrtn.career.greetinghr.com/ko/o/167441
# .....
#   -> 정보 추출 완료.
# 처리 중 (38/113): https://wrtn.career.greetinghr.com/ko/o/167938
# .....
#   -> 정보 추출 완료.
# 처리 중 (39/113): https://jobs.lever.co/welocalize/5e5fcb9d-ff9f-4f1d-8c30-c09214a0dff3
# .....
#   -> 정보 추출 완료.
# 처리 중 (40/113): https://lifeattiktok.com/search/6830867197998778631
# .....
#   -> 정보 추출 완료.
# 처리 중 (41/113): https://hanwhavision.ninehire.site/job_posting/3abiyyLV
# .....
#   -> 정보 추출 완료.
# 처리 중 (42/113): https://lifeattiktok.com/search/7190188272461859128
# .....
#   -> 정보 추출 완료.
# 처리 중 (43/113): https://toss.im/career/job-detail?job_id=5902488003
# .....
#   -> 정보 추출 완료.
# 처리 중 (44/113): https://www.lgresearch.ai/careers/view?seq=98
# .....
#   -> 정보 추출 완료.
# 처리 중 (45/113): https://www.lgresearch.ai/careers/view?seq=143
# .....
#   -> 정보 추출 완료.
# 처리 중 (46/113): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4&detailedPosition=%EA%B2%80%EC%83%89
# .....
#   -> 정보 추출 완료.
# 처리 중 (47/113): https://lifeattiktok.com/search/7388071494843582757
# .....
#   -> 정보 추출 완료.
# 처리 중 (48/113): https://hyundaimovex.careerlink.kr/jobs/RC20240119002824
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (49/113): https://career.hyperconnect.com/job/edf748a7-a883-4fef-8112-8cbfba14afa3
# .....
#   -> 정보 추출 완료.
# 처리 중 (50/113): https://gmarketcareers.ninehire.site/job_posting/71CiT5ae
# .....
#   -> 정보 추출 완료.
# 처리 중 (51/113): https://recruit.cj.net/recruit/ko/recruit/recruit/bestDetail.fo?zz_jo_num=J20250625031041
# .....
#   -> 정보 추출 완료.
# 처리 중 (52/113): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4&detailedPosition=LLM
# .....
#   -> 정보 추출 완료.
# 처리 중 (53/113): https://recruit.cj.net/recruit/ko/recruit/recruit/bestDetail.fo?zz_jo_num=J20250625030584
# .....
#   -> 정보 추출 완료.
# 처리 중 (54/113): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4&detailedPosition=Ads
# .....
#   -> 정보 추출 완료.
# 처리 중 (55/113): https://toss.im/career/job-detail?job_id=4071103003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC&detailedPosition=ETL/Pipeline%20&%20Mart
# .....
#   -> 정보 추출 완료.
# 처리 중 (56/113): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4&detailedPosition=OCR
# .....
#   -> 정보 추출 완료.
# 처리 중 (57/113): https://toss.im/career/job-detail?job_id=6072871003
# .....
#   -> 정보 추출 완료.
# 처리 중 (58/113): https://toss.im/career/job-detail?job_id=6246493003
# .....
#   -> 정보 추출 완료.
# 처리 중 (59/113): https://career.hyperconnect.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (60/113): https://hanwhavision.ninehire.site/job_posting/3abiyyLV?lang=en
# .....
#   -> 정보 추출 완료.
# 처리 중 (61/113): https://toss.im/career/job-detail?job_id=6072871003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC
# .....
#   -> 정보 추출 완료.
# 처리 중 (62/113): https://toss.im/career/job-detail?job_id=4071103003&company=%ED%86%A0%EC%8A%A4%ED%8E%98%EC%9D%B4%EB%A8%BC%EC%B8%A0&detailedPosition=Data%20Engineer
# .....
#   -> 정보 추출 완료.
# 처리 중 (63/113): https://about.daangn.com/jobs/5248527003/
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (64/113): https://career.hyperconnect.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (65/113): https://toss.im/career/job-detail?job_id=4071103003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC&detailedPosition=%EA%B4%80%EB%A6%AC%ED%9A%8C%EA%B3%84
# .....
#   -> 정보 추출 완료.
# 처리 중 (66/113): https://toss.im/career/job-detail?job_id=4071103003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC
# .....
#   -> 정보 추출 완료.
# 처리 중 (67/113): https://career.hyperconnect.com/job/5d4fe20e-3f1e-4137-baff-4eae04cd209e
# .....
#   -> 정보 추출 완료.
# 처리 중 (68/113): https://jobs.lever.co/welocalize/b0eecd6c-dffd-4f7d-9cbe-d8b8c2498691
# .....
#   -> 정보 추출 완료.
# 처리 중 (69/113): https://careers.gmarket.com/job_posting/71CiT5ae
# .....
#   -> 정보 추출 완료.
# 처리 중 (70/113): https://toss.im/career/job-detail?job_id=6543523003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC&detailedPosition=General
# .....
#   -> 정보 추출 완료.
# 처리 중 (71/113): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC&detailedPosition=Product
# .....
#   -> 정보 추출 완료.
# 처리 중 (72/113): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC
# .....
#   -> 정보 추출 완료.
# 처리 중 (73/113): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4%EC%A6%9D%EA%B6%8C&detailedPosition=LLM/Platform
# .....
#   -> 정보 추출 완료.
# 처리 중 (74/113): https://toss.im/career/job-detail?job_id=4071103003&company=%ED%86%A0%EC%8A%A4%ED%8E%98%EC%9D%B4%EB%A8%BC%EC%B8%A0
# .....
#   -> 정보 추출 완료.
# 처리 중 (75/113): https://toss.im/career/job-detail?job_id=4071103003&company=%ED%86%A0%EC%8A%A4%ED%8E%98%EC%9D%B4%EB%A8%BC%EC%B8%A0&detailedPosition=%EA%B3%B5%ED%86%B5
# .....
#   -> 정보 추출 완료.
# 처리 중 (76/113): https://www.wanted.co.kr/wd/299115?client_id=ubRphx9ewFwQvQV3kyJjjFSp&utm_source=zighang&utm_medium=referral
# .....
#   -> 정보 추출 완료.
# 처리 중 (77/113): https://toss.im/career/job-detail?job_id=4071103003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC&detailedPosition=Product
# .....
#   -> 정보 추출 완료.
# 처리 중 (78/113): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4&detailedPosition=Product
# .....
#   -> 정보 추출 완료.
# 처리 중 (79/113): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC&detailedPosition=General
# .....
#   -> 정보 추출 완료.
# 처리 중 (80/113): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4&detailedPosition=Platform
# .....
#   -> 정보 추출 완료.
# 처리 중 (81/113): https://career.hyperconnect.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (82/113): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4%EC%A6%9D%EA%B6%8C
# .....
#   -> 정보 추출 완료.
# 처리 중 (83/113): https://career.shiftup.co.kr/ko/o/101648
# .....
#   -> 정보 추출 완료.
# 처리 중 (84/113): https://cosmax.recruiter.co.kr/career/jobs/30973
# .....
#   -> 정보 추출 완료.
# 처리 중 (85/113): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC&detailedPosition=Loan
# .....
#   -> 정보 추출 완료.
# 처리 중 (86/113): https://career.megazone.com/job_posting/3PEDJjUr
# .....
#   -> 정보 추출 완료.
# 처리 중 (87/113): https://toss.im/career/job-detail?job_id=5167730003
# .....
#   -> 정보 추출 완료.
# 처리 중 (88/113): https://career.shiftup.co.kr/ko/o/130990
# .....
#   -> 정보 추출 완료.
# 처리 중 (89/113): https://www.rallit.com/positions/1679/ga-aa-%EB%8D%B0%EC%9D%B4%ED%84%B0-%EB%B6%84%EC%84%9D%EA%B0%80?client_id=anonymous_user&utm_medium=referral&utm_source=zighang&zighang_source_url=https%3A%2F%2Fzighang.com%2Frecruitment%2F6c7fd3c4-7baa-48c8-a028-5d4b22b36ca8
# .....
#   -> 정보 추출 완료.
# 처리 중 (90/113): https://tydtr0dj.ninehire.site/job_posting/0Eu5yjmY
# .....
#   -> 정보 추출 완료.
# 처리 중 (91/113): https://careers.upstage.ai/o/wbl-ai-research-engineer-llm-post-training
# .....
#   -> 정보 추출 완료.
# 처리 중 (92/113): https://www.wanted.co.kr/wd/303570?client_id=ubRphx9ewFwQvQV3kyJjjFSp&utm_source=zighang&utm_medium=referral
# .....
#   -> 정보 추출 완료.
# 처리 중 (93/113): https://toss.im/career/job-detail?job_id=6072871003&company=%ED%86%A0%EC%8A%A4
# .....
#   -> 정보 추출 완료.
# 처리 중 (94/113): https://www.wanted.co.kr/wd/304144?client_id=ubRphx9ewFwQvQV3kyJjjFSp&utm_source=zighang&utm_medium=referral
# .....
#   -> 정보 추출 완료.
# 처리 중 (95/113): https://about.daangn.com/jobs/6610455003/
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (96/113): https://career.megazone.com/job_posting/OHLZ8eQm
# .....
#   -> 정보 추출 완료.
# 처리 중 (97/113): https://recruit.kreamcorp.com/rcrt/view.do?annoId=30003527&lang=ko
# .....
#   -> 정보 추출 완료.
# 처리 중 (98/113): https://recruit.kreamcorp.com/rcrt/view.do?annoId=30003529&lang=ko
# .....
#   -> 정보 추출 완료.
# 처리 중 (99/113): https://about.daangn.com/jobs/4300801003/
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (100/113): https://toss.im/career/job-detail?job_id=5167730003&company=%ED%86%A0%EC%8A%A4%ED%94%8C%EB%A0%88%EC%9D%B4%EC%8A%A4
# .....
#   -> 정보 추출 완료.
# 처리 중 (101/113): https://recruit.douzone.com/post/8000/REM2025012
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (102/113): https://about.daangn.com/jobs/5663836003/
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (103/113): https://career.megazone.com/job_posting/Ny4RuZjf
# .....
#   -> 정보 추출 완료.
# 처리 중 (104/113): https://career.megazone.com/job_posting/IB6eljSQ
# .....
#   -> 정보 추출 완료.
# 처리 중 (105/113): https://career.megazone.com/job_posting/Ny4RuZjf?lang=en
# .....
#   -> 정보 추출 완료.
# 처리 중 (106/113): https://career.megazone.com/job_posting/OHLZ8eQm?lang=en
# .....
#   -> 정보 추출 완료.
# 처리 중 (107/113): https://career.megazone.com/job_posting/IB6eljSQ?lang=en
# .....
#   -> 정보 추출 완료.
# 처리 중 (108/113): https://careers.upstage.ai//o/ai-product-data-manager
# .....
#   -> 정보 추출 완료.
# 처리 중 (109/113): https://www.ibkonejob.co.kr/jp/ema/recruitDetailView.do?hireSn=001009866
# .....
#   -> 정보 추출 완료.
# 처리 중 (110/113): https://day1company.ninehire.site/job_posting/qqsxM2hR
# .....
#   -> 정보 추출 완료.
# 처리 중 (111/113): https://jobs.lever.co/welocalize/22dcddda-15da-406f-94a9-326ce3f1509b
# .....
#   -> 정보 추출 완료.
# 처리 중 (112/113): https://jobs.lever.co/welocalize/4a4d7a35-66e3-427a-97bc-66fd66ee5940
# .....
#   -> 정보 추출 완료.
# 처리 중 (113/113): https://recruit.incruit.com/wooribank/job/2406140003
# .....
#   -> 정보 추출 완료.
#
# 작업 완료!
#
# 최종 결과 산출 완료.
# 총 소요 시간: 5792.0초 (96.5분)

# %%
output_filename = f'sheets/ai_jobs_final_results_{formatted_date}.xlsx'
result_df.to_excel(output_filename, index=False)

# %%
# 자격요건 또는 우대사항이 null이거나 '추출 실패'인 행만 추출
fail_df = result_df[
    result_df["자격요건"].isnull()
    | result_df["우대사항"].isnull()
    | (result_df["자격요건"] == "추출 실패")
    | (result_df["우대사항"] == "추출 실패")
    | (result_df["자격요건"] == "")
    | (result_df["우대사항"] == "")
]

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   회사      133 non-null    object
#  1   제목      133 non-null    object
#  2   경력      133 non-null    object
#  3   근무형태    133 non-null    object
#  4   학력      133 non-null    object
#  5   근무지역    133 non-null    object
#  6   링크      133 non-null    object
#  7   지원 링크   133 non-null    object
#  8   자격요건    133 non-null    object
#  9   우대사항    133 non-null    object
# dtypes: object(10)
# memory usage: 10.5+ KB

# %%
fail_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66 entries, 0 to 132
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   회사      66 non-null     object
#  1   제목      66 non-null     object
#  2   경력      66 non-null     object
#  3   근무형태    66 non-null     object
#  4   학력      66 non-null     object
#  5   근무지역    66 non-null     object
#  6   링크      66 non-null     object
#  7   지원 링크   66 non-null     object
#  8   자격요건    66 non-null     object
#  9   우대사항    66 non-null     object
# dtypes: object(10)
# memory usage: 5.7+ KB

# %%
start_time = time.time()  # 시작 시간 기록

max_attempts = 10
attempt = 1

while attempt < max_attempts:
    # 자격요건 또는 우대사항이 null이거나 '추출 실패'인 행만 추출
    fail_df = result_df[
        result_df["자격요건"].isnull()
        | result_df["우대사항"].isnull()
        | (result_df["자격요건"] == "추출 실패")
        | (result_df["우대사항"] == "추출 실패")
        | (result_df["자격요건"] == "")
        | (result_df["우대사항"] == "")
    ]

    # 모두 정상적으로 추출되었으면 반복 종료
    if fail_df.empty:
        break

    print(f"\n=== {attempt+1}번째 재시도: {len(fail_df)}건 ===")
    # 실패한 행만 main 함수에 재전달
    if "자격요건" in fail_df.columns and "우대사항" in fail_df.columns:
        fail_df = fail_df.drop(columns=["자격요건", "우대사항"])
    retry_result = main(fail_df)

    # 기존 result_df에서 실패한 부분만 retry_result로 업데이트
    for idx, row in retry_result.iterrows():
        mask = result_df["지원 링크"] == row["지원 링크"]
        result_df.loc[mask, ["자격요건", "우대사항"]] = row[
            ["자격요건", "우대사항"]
        ].values

    attempt += 1
    
print('종료')
# Out:
# === 2번째 재시도: 66건 ===
# 처리 중 (1/66): https://jobs.careers.microsoft.com/global/en/job/1856383
# .....
#   -> 정보 추출 완료.
# 처리 중 (18/66): https://toss.im/career/job-detail?job_id=4100792003
# .....
#   -> 정보 추출 완료.
# 처리 중 (19/66): https://medtronic.wd1.myworkdayjobs.com/en-US/MedtronicCareers/job/Seoul-Seoul-Korea/Korea-Channel-Data-Analyst--Contract-_R37500?locationCountry=7a5a2aadf9d34086a2bfbfd408bc28da
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (20/66): https://tydtr0dj.ninehire.site/job_posting/CG6BujWw
# .....
#   -> 정보 추출 완료.
# 처리 중 (22/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (23/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (24/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (25/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (26/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (27/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (28/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (29/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (30/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (31/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (32/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (33/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (34/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (35/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (36/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (37/66): https://kakaopay.career.greetinghr.com/ko/o/158068
# .....
#   -> 정보 추출 완료.
# 처리 중 (38/66): https://www.gsneotek.com/job_openings/?q=YToxOntzOjEyOiJrZXl3b3JkX3R5cGUiO3M6MzoiYWxsIjt9&bmode=view&idx=167354283&t=board//
# .....
#   -> 정보 추출 완료.
# 처리 중 (40/66): https://koreainvestment-recruit.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (52/66): https://jobs.lever.co/welocalize/5e5fcb9d-ff9f-4f1d-8c30-c09214a0dff3
# .....
#   -> 정보 추출 완료.
# 처리 중 (59/66): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4&detailedPosition=%EA%B2%80%EC%83%89
# .....
#   -> 정보 추출 완료.
# 처리 중 (61/66): https://hyundaimovex.careerlink.kr/jobs/RC20240119002824
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (65/66): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4&detailedPosition=LLM
# .....
#   -> 정보 추출 완료.
# 처리 중 (67/66): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4&detailedPosition=Ads
# .....
#   -> 정보 추출 완료.
# 처리 중 (68/66): https://toss.im/career/job-detail?job_id=4071103003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC&detailedPosition=ETL/Pipeline%20&%20Mart
# .....
#   -> 정보 추출 완료.
# 처리 중 (69/66): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4&detailedPosition=OCR
# .....
#   -> 정보 추출 완료.
# 처리 중 (71/66): https://toss.im/career/job-detail?job_id=6246493003
# .....
#   -> 정보 추출 완료.
# 처리 중 (72/66): https://career.hyperconnect.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (73/66): https://career.hyperconnect.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (74/66): https://career.hyperconnect.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (78/66): https://about.daangn.com/jobs/5248527003/
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (79/66): https://career.hyperconnect.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (80/66): https://career.hyperconnect.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (81/66): https://career.hyperconnect.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (82/66): https://toss.im/career/job-detail?job_id=4071103003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC&detailedPosition=%EA%B4%80%EB%A6%AC%ED%9A%8C%EA%B3%84
# .....
#   -> 정보 추출 완료.
# 처리 중 (85/66): https://jobs.lever.co/welocalize/b0eecd6c-dffd-4f7d-9cbe-d8b8c2498691
# .....
#   -> 정보 추출 완료.
# 처리 중 (87/66): https://toss.im/career/job-detail?job_id=6543523003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC&detailedPosition=General
# .....
#   -> 정보 추출 완료.
# 처리 중 (88/66): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC&detailedPosition=Product
# .....
#   -> 정보 추출 완료.
# 처리 중 (89/66): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC
# .....
#   -> 정보 추출 완료.
# 처리 중 (90/66): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4%EC%A6%9D%EA%B6%8C&detailedPosition=LLM/Platform
# .....
#   -> 정보 추출 완료.
# 처리 중 (92/66): https://toss.im/career/job-detail?job_id=4071103003&company=%ED%86%A0%EC%8A%A4%ED%8E%98%EC%9D%B4%EB%A8%BC%EC%B8%A0&detailedPosition=%EA%B3%B5%ED%86%B5
# .....
#   -> 정보 추출 완료.
# 처리 중 (93/66): https://www.wanted.co.kr/wd/299115?client_id=ubRphx9ewFwQvQV3kyJjjFSp&utm_source=zighang&utm_medium=referral
# .....
#   -> 정보 추출 완료.
# 처리 중 (94/66): https://toss.im/career/job-detail?job_id=4071103003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC&detailedPosition=Product
# .....
#   -> 정보 추출 완료.
# 처리 중 (95/66): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4&detailedPosition=Product
# .....
#   -> 정보 추출 완료.
# 처리 중 (97/66): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4&detailedPosition=Platform
# .....
#   -> 정보 추출 완료.
# 처리 중 (98/66): https://career.hyperconnect.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (99/66): https://career.hyperconnect.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (100/66): https://career.hyperconnect.com/
# .....
#   -> 정보 추출 완료.
# 처리 중 (101/66): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4%EC%A6%9D%EA%B6%8C
# .....
#   -> 정보 추출 완료.
# 처리 중 (103/66): https://cosmax.recruiter.co.kr/career/jobs/30973
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (104/66): https://toss.im/career/job-detail?job_id=4553599003&company=%ED%86%A0%EC%8A%A4%EB%B1%85%ED%81%AC&detailedPosition=Loan
# .....
#   -> 정보 추출 완료.
# 처리 중 (106/66): https://toss.im/career/job-detail?job_id=5167730003
# .....
#   -> 정보 추출 완료.
# 처리 중 (109/66): https://tydtr0dj.ninehire.site/job_posting/0Eu5yjmY
# .....
#   -> 정보 추출 완료.
# 처리 중 (112/66): https://www.wanted.co.kr/wd/303570?client_id=ubRphx9ewFwQvQV3kyJjjFSp&utm_source=zighang&utm_medium=referral
# .....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 25
#      23 if "자격요건" in fail_df.columns and "우대사항" in fail_df.columns:
#      24     fail_df = fail_df.drop(columns=["자격요건", "우대사항"])
# ---> 25 retry_result = main(fail_df)
#      27 # 기존 result_df에서 실패한 부분만 retry_result로 업데이트
#      28 for idx, row in retry_result.iterrows():
#
# Cell In[6], line 41, in main(df)
#      39 # LLM을 호출하여 정보 추출
#      40 print(".....")
# ---> 41 extracted_info = call_local_llm(main_text)
#      43 if extracted_info:
#      44     job_data["자격요건"] = "\n".join(extracted_info.get("자격요건", []))
#
# Cell In[5], line 39, in call_local_llm(html_content)
#      32 data = {
#      33     "model": MODEL_NAME,
#      34     "messages": [{"role": "user", "content": prompt}],
#      35     "temperature": 0.0,
#      36 }
#      38 try:
# ---> 39     response = requests.post(
#      40         API_URL, headers=headers, data=json.dumps(data), timeout=300
#      41     )
#      42     response.raise_for_status()
#      43     response_json = response.json()
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
start_time = time.time()  # 시작 시간 기록

max_attempts = 10
attempt = 1

while attempt < max_attempts:
    # 자격요건 또는 우대사항이 null이거나 '추출 실패'인 행만 추출
    fail_df = result_df[
        result_df["자격요건"].isnull()
        | result_df["우대사항"].isnull()
        | (result_df["자격요건"] == "추출 실패")
        | (result_df["우대사항"] == "추출 실패")
        | (result_df["자격요건"] == "")
        | (result_df["우대사항"] == "")
    ]

    # 모두 정상적으로 추출되었으면 반복 종료
    if fail_df.empty:
        break

    print(f"\n=== {attempt+1}번째 재시도: {len(fail_df)}건 ===")
    # 실패한 행만 main 함수에 재전달
    if "자격요건" in fail_df.columns and "우대사항" in fail_df.columns:
        fail_df = fail_df.drop(columns=["자격요건", "우대사항"])
    retry_result = main(fail_df)

    # 기존 result_df에서 실패한 부분만 retry_result로 업데이트
    for idx, row in retry_result.iterrows():
        mask = result_df["지원 링크"] == row["지원 링크"]
        result_df.loc[mask, ["자격요건", "우대사항"]] = row[
            ["자격요건", "우대사항"]
        ].values

    attempt += 1

# 최종 결과 분리
fail_df = result_df[
    result_df["자격요건"].isnull()
    | result_df["우대사항"].isnull()
    | (result_df["자격요건"] == "추출 실패")
    | (result_df["우대사항"] == "추출 실패")
]
success_df = result_df[
    result_df["자격요건"].notnull()
    & result_df["우대사항"].notnull()
    & (result_df["자격요건"] != "추출 실패")
    & (result_df["우대사항"] != "추출 실패")
]

output_filename = f"sheets/ai_jobs_final_results_{formatted_date}.xlsx"
result_df.to_excel(output_filename, index=False)

end_time = time.time()  # 종료 시간 기록
elapsed = end_time - start_time
print(f"\n최종 결과가 '{output_filename}' 파일에 저장되었습니다.")
print(f"총 소요 시간: {elapsed:.1f}초 ({elapsed/60:.1f}분)")
# Out:
# 처리 중 (1/113): https://jobs.careers.microsoft.com/global/en/job/1856383
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-898",
#   "object": "chat.completion",
#   "created": 1756727161,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [],\n  \"우대사항\": []\n}",
#         "reasoning": "The user says: \"다음은 채용 공고 페이지의 내용입니다. 이 내용에서 '자격요건'과 '우대사항'을 찾아서 각각 정리하라. 결과는 반드시 아래와 같은 JSON 형식으로만 응답하라. 만약 내용이 없다면 빈 리스트([])로 응답하라.\"\n\nThen they provide a placeholder: \"--- 공고 내용 시작 --- Loading... --- 공고 내용 끝 ---\"\n\nIt seems the actual content is not provided; it's just \"Loading...\". So there is no content. According to instruction, if content is missing, we should return empty lists for both.\n\nThus output:\n\n{\n  \"자격요건\": [],\n  \"우대사항\": []\n}\n\nWe must respond only in JSON format. No other text."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 212,
#     "completion_tokens": 191,
#     "total_tokens": 403
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [],
#   "우대사항": []
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (2/113): https://recruit.navercloudcorp.com/rcrt/view.do?annoId=30003735&lang=ko
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-994",
#   "object": "chat.completion",
#   "created": 1756727211,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"국내/외 정규대학 박사 학위 보유자 혹은 2년 이상 의 유관 업무 경험이 있으신 분\",\n    \"Computer Vision, Video Processing, Multimodal 관련 기술 개발 경험이 있으신 분\",\n    \"PyTorch, Huggingface 등 AI Model 개발 및 추론을 위한 Framework에 익숙하신 분\"\n  ],\n  \"우대사항\": [\n    \"대규모 분산 훈련 및 모델 가속화 관련 경험을 보유하신 분\",\n    \"AI 기반 서비스 개발/프로젝트에 높은 기여도로 성공 경험을 보유하신 분\",\n    \"Challenge 입상 또는 Top-tier 논문 경험을 보유하신 분\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting includes a section:\n\n자격요건 - ... (list)\n우대사항 - ... (list)\n\nWe need to parse them. The text:\n\n자격요건 - 국내/외 정규대학 박사 학위 보유자 혹은 2년 이상 의 유관 업무 경험이 있으신 분 - Computer Vision, Video Processing, Multimodal 관련 기술 개발 경험이 있으신 분 - PyTorch, Huggingface 등 AI Model 개발 및 추론을 위한 Framework에 익숙하신 분\n\n우대사항 - 대규모 분산 훈련 및 모델 가속화 관련 경험을 보유하신 분 - AI 기반 서비스 개발/프로젝트에 높은 기여도로 성공 경험을 보유하신 분 - Challenge 입상 또는 Top-tier 논문 경험을 보유하신 분\n\nWe need to output JSON with arrays of strings. Each bullet point is a separate string. Ensure no trailing spaces. The JSON must be exactly as specified. Provide empty lists if none. But we have both.\n\nThus output:\n\n{\n  \"자격요건\": [\n    \"국내/외 정규대학 박사 학위 보유자 혹은 2년 이상 의 유관 업무 경험이 있으신 분\",\n    \"Computer Vision, Video Processing, Multimodal 관련 기술 개발 경험이 있으신 분\",\n    \"PyTorch, Huggingface 등 AI Model 개발 및 추론을 위한 Framework에 익숙하신 분\"\n  ],\n  \"우대사항\": [\n    \"대규모 분산 훈련 및 모델 가속화 관련 경험을 보유하신 분\",\n    \"AI 기반 서비스 개발/프로젝트에 높은 기여도로 성공 경험을 보유하신 분\",\n    \"Challenge 입상 또는 Top-tier 논문 경험을 보유하신 분\"\n  ]\n}\n\nCheck formatting: JSON with double quotes. Ensure no trailing commas. Provide exactly."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 2398,
#     "completion_tokens": 591,
#     "total_tokens": 2989
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "국내/외 정규대학 박사 학위 보유자 혹은 2년 이상 의 유관 업무 경험이 있으신 분",
#     "Computer Vision, Video Processing, Multimodal 관련 기술 개발 경험이 있으신 분",
#     "PyTorch, Huggingface 등 AI Model 개발 및 추론을 위한 Framework에 익숙하신 분"
#   ],
#   "우대사항": [
#     "대규모 분산 훈련 및 모델 가속화 관련 경험을 보유하신 분",
#     "AI 기반 서비스 개발/프로젝트에 높은 기여도로 성공 경험을 보유하신 분",
#     "Challenge 입상 또는 Top-tier 논문 경험을 보유하신 분"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (3/113): https://www.lgresearch.ai/careers/view?seq=250
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-191",
#   "object": "chat.completion",
#   "created": 1756727270,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"컴퓨터과학, 컴퓨터공학 등 관련 전공 학/석사 재학생 또는 졸업생\",\n    \"Python 등 하나 이상의 프로그래밍 언어 활용 가능하신 분\",\n    \"리눅스 환경에서의 개발 및 작업에 익숙하신 분\",\n    \"Git 등 형상 관리 툴 사용 경험이 있으신 분\",\n    \"영문 금융 문서(예: SEC 공시 자료) 수준의 해석이 가능하신 분\",\n    \"금융 및 회계 용어(예: 재무제표, 회계 개념, 증권 용어 등)에 대한 기본적인 이해가 있으신 분\"\n  ],\n  \"우대사항\": [\n    \"데이터 처리 및 분석 관련 프로젝트 경험 보유\",\n    \"금융 데이터 또는 자연어 처리(NLP) 관련 경험 보유\",\n    \"Kubernetes, Dagster, Airflow 등 워크플로우 및 오케스트레이션 도구 사용 경험 보유\",\n    \"분산 학습 프레임워크(DP, DDP, FSDP, DeepSpeed 등) 활용 경험\",\n    \"대규모 언어 모델(LLM) 파인튜닝 경험\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting includes a section \"지원자격\" (which is likely '자격요건') and \"우대사항\". Let's locate them.\n\nScrolling: There's a section \"지원자격\" near the end: \"지원자격 컴퓨터과학, 컴퓨터공학 등 관련 전공 학/석사 재학생 또는 졸업생 Python 등 하나 이상의 프로그래밍 언어 활용 가능하신 분 리눅스 환경에서의 개발 및 작업에 익숙하신 분 Git 등 형상 관리 툴 사용 경험이 있으신 분 영문 금융 문서(예: SEC 공시 자료) 수준의 해석이 가능하신 분 금융 및 회계 용어(예: 재무제표, 회계 개념, 증권 용어 등)에 대한 기본적인 이해가 있으신 분\"\n\nThen \"우대사항\" section: \"우대사항 데이터 처리 및 분석 관련 프로젝트 경험 보유 금융 데이터 또는 자연어 처리(NLP) 관련 경험 보유 Kubernetes, Dagster, Airflow 등 워크플로우 및 오케스트레이션 도구 사용 경험 보유 분산 학습 프레임워크(DP, DDP, FSDP, DeepSpeed 등) 활용 경험 대규모 언어 모델(LLM) 파인튜닝 경험\"\n\nThus we need to output JSON with arrays of strings. Each bullet point as separate string. Ensure no extra spaces. The strings should match exactly as in the text? Probably trimmed. Let's produce:\n\n\"자격요건\": [\n\"컴퓨터과학, 컴퓨터공학 등 관련 전공 학/석사 재학생 또는 졸업생\",\n\"Python 등 하나 이상의 프로그래밍 언어 활용 가능하신 분\",\n\"리눅스 환경에서의 개발 및 작업에 익숙하신 분\",\n\"Git 등 형상 관리 툴 사용 경험이 있으신 분\",\n\"영문 금융 문서(예: SEC 공시 자료) 수준의 해석이 가능하신 분\",\n\"금융 및 회계 용어(예: 재무제표, 회계 개념, 증권 용어 등)에 대한 기본적인 이해가 있으신 분\"\n]\n\n\"우대사항\": [\n\"데이터 처리 및 분석 관련 프로젝트 경험 보유\",\n\"금융 데이터 또는 자연어 처리(NLP) 관련 경험 보유\",\n\"Kubernetes, Dagster, Airflow 등 워크플로우 및 오케스트레이션 도구 사용 경험 보유\",\n\"분산 학습 프레임워크(DP, DDP, FSDP, DeepSpeed 등) 활용 경험\",\n\"대규모 언어 모델(LLM) 파인튜닝 경험\"\n]\n\nReturn JSON."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 1898,
#     "completion_tokens": 860,
#     "total_tokens": 2758
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "컴퓨터과학, 컴퓨터공학 등 관련 전공 학/석사 재학생 또는 졸업생",
#     "Python 등 하나 이상의 프로그래밍 언어 활용 가능하신 분",
#     "리눅스 환경에서의 개발 및 작업에 익숙하신 분",
#     "Git 등 형상 관리 툴 사용 경험이 있으신 분",
#     "영문 금융 문서(예: SEC 공시 자료) 수준의 해석이 가능하신 분",
#     "금융 및 회계 용어(예: 재무제표, 회계 개념, 증권 용어 등)에 대한 기본적인 이해가 있으신 분"
#   ],
#   "우대사항": [
#     "데이터 처리 및 분석 관련 프로젝트 경험 보유",
#     "금융 데이터 또는 자연어 처리(NLP) 관련 경험 보유",
#     "Kubernetes, Dagster, Airflow 등 워크플로우 및 오케스트레이션 도구 사용 경험 보유",
#     "분산 학습 프레임워크(DP, DDP, FSDP, DeepSpeed 등) 활용 경험",
#     "대규모 언어 모델(LLM) 파인튜닝 경험"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (4/113): https://career.doosan.com/dsp/sa/RecList.jsp?REC_ID=1000353083&mode=goDetail
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-966",
#   "object": "chat.completion",
#   "created": 1756727350,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"정규 4년제 대학교(이상) 졸업자 및 '26년 2월 졸업예정자\",\n    \"인턴십 근무 ('25년 11월~12월 중, 4주) 및 '26년 1월 중 입사 가능자\",\n    \"모집분야 관련 전공/자격요건 이외에도 동일 전문성을 갖추고 있는 자는 지원 가능\",\n    \"어학 : 지원서 제출 마감일 기준 2년 이내 취득한 공인영어성적 보유자 - TOEIC Speaking 또는 OPIc : 인문 IM(Intermediate Mid), 이공 IL(Intermediate Low)등급 이상\",\n    \"병역필 또는 면제자, 해외 근무에 결격사유 없는 자\"\n  ],\n  \"우대사항\": [\n    \"Python 등 프로그래밍 언어 가능 및 기본 ML/DL 이해\",\n    \"AI 관련 인턴십/해커톤/공모전 등 경험 보유\",\n    \"영어 커뮤니케이션 우수자 지역 동대문\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting includes a section labeled '자격요건' and '우대사항' earlier. Let's parse.\n\nThe posting includes:\n\n- Under \"전공\" and \"우대사항\" earlier: \n  - \"우대사항\" list: \n    - Python 등 프로그래밍 언어 가능 및 기본 ML/DL 이해\n    - AI 관련 인턴십/해커톤/공모전 등 경험 보유\n    - 영어 커뮤니케이션 우수자 지역 동대문\n\nBut also later there's a separate \"자격요건\" section:\n\n\"자격요건 * 정규 4년제 대학교(이상) 졸업자 및 '26년 2월 졸업예정자 * 인턴십 근무 ('25년 11월~12월 중, 4주) 및 '26년 1월 중 입사 가능자 * 모집분야 관련 전공/자격요건 이외에도 동일 전문성을 갖추고 있는 자는 지원 가능 * 어학 : 지원서 제출 마감일 기준 2년 이내 취득한 공인영어성적 보유자 - TOEIC Speaking 또는 OPIc : 인문 IM(Intermediate Mid), 이공 IL(Intermediate Low)등급 이상 * 병역필 또는 면제자, 해외 근무에 결격사유 없는 자\"\n\nSo we need to list all items under 자격요건. The bullet points are:\n\n- 정규 4년제 대학교(이상) 졸업자 및 '26년 2월 졸업예정자\n- 인턴십 근무 ('25년 11월~12월 중, 4주) 및 '26년 1월 중 입사 가능자\n- 모집분야 관련 전공/자격요건 이외에도 동일 전문성을 갖추고 있는 자는 지원 가능\n- 어학 : 지원서 제출 마감일 기준 2년 이내 취득한 공인영어성적 보유자 - TOEIC Speaking 또는 OPIc : 인문 IM(Intermediate Mid), 이공 IL(Intermediate Low)등급 이상\n- 병역필 또는 면제자, 해외 근무에 결격사유 없는 자\n\nWe might need to separate the subpoints. The bullet list includes sub-bullets for 어학. We can treat each as separate items. The JSON expects array of strings. So we can include each bullet as a string. For the 어학 bullet, we can combine into one string: \"어학 : 지원서 제출 마감일 기준 2년 이내 취득한 공인영어성적 보유자 - TOEIC Speaking 또는 OPIc : 인문 IM(Intermediate Mid), 이공 IL(Intermediate Low)등급 이상\". Or we can split into two items: \"공인영어성적 보유자 (TOEIC Speaking 또는 OPIc : 인문 IM, 이공 IL 등급 이상)\" and \"어학\". But likely keep as one.\n\nAlso earlier \"우대사항\" list: 3 items. But also earlier \"우대사항\" includes \"영어 커뮤니케이션 우수자 지역 동대문\" which seems odd. It might be \"영어 커뮤니케이션 우수자\" and \"지역 동대문\" maybe separate. But we can keep as one string: \"영어 커뮤니케이션 우수자 지역 동대문\". But maybe better to separate: \"영어 커뮤니케이션 우수자\" and \"지역 동대문\". But the original bullet: \"- 영어 커뮤니케이션 우수자 지역 동대문\" maybe means \"영어 커뮤니케이션 우수자\" and \"지역 동대문\" as separate. But we can keep as one string.\n\nAlso there is a later \"기타사항\" that includes \"국가보훈대상자 및 국가등록장애인은 관련 법에 의거하여 우대됩니다.\" But that's not under 우대사항. So we ignore.\n\nThus final JSON:\n\n{\n  \"자격요건\": [\n    \"정규 4년제 대학교(이상) 졸업자 및 '26년 2월 졸업예정자\",\n    \"인턴십 근무 ('25년 11월~12월 중, 4주) 및 '26년 1월 중 입사 가능자\",\n    \"모집분야 관련 전공/자격요건 이외에도 동일 전문성을 갖추고 있는 자는 지원 가능\",\n    \"어학 : 지원서 제출 마감일 기준 2년 이내 취득한 공인영어성적 보유자 - TOEIC Speaking 또는 OPIc : 인문 IM(Intermediate Mid), 이공 IL(Intermediate Low)등급 이상\",\n    \"병역필 또는 면제자, 해외 근무에 결격사유 없는 자\"\n  ],\n  \"우대사항\": [\n    \"Python 등 프로그래밍 언어 가능 및 기본 ML/DL 이해\",\n    \"AI 관련 인턴십/해커톤/공모전 등 경험 보유\",\n    \"영어 커뮤니케이션 우수자 지역 동대문\"\n  ]\n}\n\nCheck formatting: JSON with double quotes. Ensure no trailing commas. Provide only JSON."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 1255,
#     "completion_tokens": 1391,
#     "total_tokens": 2646
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "정규 4년제 대학교(이상) 졸업자 및 '26년 2월 졸업예정자",
#     "인턴십 근무 ('25년 11월~12월 중, 4주) 및 '26년 1월 중 입사 가능자",
#     "모집분야 관련 전공/자격요건 이외에도 동일 전문성을 갖추고 있는 자는 지원 가능",
#     "어학 : 지원서 제출 마감일 기준 2년 이내 취득한 공인영어성적 보유자 - TOEIC Speaking 또는 OPIc : 인문 IM(Intermediate Mid), 이공 IL(Intermediate Low)등급 이상",
#     "병역필 또는 면제자, 해외 근무에 결격사유 없는 자"
#   ],
#   "우대사항": [
#     "Python 등 프로그래밍 언어 가능 및 기본 ML/DL 이해",
#     "AI 관련 인턴십/해커톤/공모전 등 경험 보유",
#     "영어 커뮤니케이션 우수자 지역 동대문"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (5/113): https://recruit.navercloudcorp.com/rcrt/view.do?annoId=30003836&lang=ko
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-355",
#   "object": "chat.completion",
#   "created": 1756727402,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"국내/외 정규대학(학사) 재학생 또는 기졸업자\",\n    \"인턴십 기간(약 3개월) 동안 Full-Time 근무가 가능하신 분\",\n    \"Multimodal Language Model (LLaVA, Qwen VL, DeepSeek VL)에 대한 기본적인 지식 및 학습 과정에 대한 이해를 갖추신 분\",\n    \"각 학습 단계별 Multimodal LLM 데이터의 특성, 종류에 대한 이해 및 신규 데이터 디자인 능력을 갖추신 분\",\n    \"Python 활용 능력을 갖추신 분\"\n  ],\n  \"우대사항\": [\n    \"Model Driven Data Filtering & Curation 지식이나 경험 이 있으신 분\",\n    \"최소 1개월 이상 소요된, 팀 프로젝트를 성공적으로 완료한 경험 이 있으신 분\",\n    \"LLM or Multimodal LLM 관련 Top Tier 논문 작성 경험 이 있으신 분\",\n    \"Challenge 참가 경험 또는 상위 입상 경험이 있으신 분\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting includes a section \"지원자격\" and \"우대사항\". We need to list each requirement as separate strings.\n\nLet's parse:\n\n지원자격 (qualifications):\n\n- 국내/외 정규대학(학사) 재학생 또는 기졸업자\n- 인턴십 기간(약 3개월) 동안 Full-Time 근무가 가능하신 분\n- Multimodal Language Model (LLaVA, Qwen VL, DeepSeek VL)에 대한 기본적인 지식 및 학습 과정에 대한 이해를 갖추신 분\n- 각 학습 단계별 Multimodal LLM 데이터의 특성, 종류에 대한 이해 및 신규 데이터 디자인 능력을 갖추신 분\n- Python 활용 능력을 갖추신 분\n\n우대사항 (preferential):\n\n- Model Driven Data Filtering & Curation 지식이나 경험 이 있으신 분\n- 최소 1개월 이상 소요된, 팀 프로젝트를 성공적으로 완료한 경험 이 있으신 분\n- LLM or Multimodal LLM 관련 Top Tier 논문 작성 경험 이 있으신 분\n- Challenge 참가 경험 또는 상위 입상 경험이 있으신 분\n\nAlso note: \"국가유공자 및 장애인 등 취업보호 대상자는 관계법령에 따라 우대합니다.\" But that's a general statement. The specific 우대사항 list is above. We should include only the listed items.\n\nThus JSON:\n\n{\n  \"자격요건\": [\n    \"국내/외 정규대학(학사) 재학생 또는 기졸업자\",\n    \"인턴십 기간(약 3개월) 동안 Full-Time 근무가 가능하신 분\",\n    \"Multimodal Language Model (LLaVA, Qwen VL, DeepSeek VL)에 대한 기본적인 지식 및 학습 과정에 대한 이해를 갖추신 분\",\n    \"각 학습 단계별 Multimodal LLM 데이터의 특성, 종류에 대한 이해 및 신규 데이터 디자인 능력을 갖추신 분\",\n    \"Python 활용 능력을 갖추신 분\"\n  ],\n  \"우대사항\": [\n    \"Model Driven Data Filtering & Curation 지식이나 경험 이 있으신 분\",\n    \"최소 1개월 이상 소요된, 팀 프로젝트를 성공적으로 완료한 경험 이 있으신 분\",\n    \"LLM or Multimodal LLM 관련 Top Tier 논문 작성 경험 이 있으신 분\",\n    \"Challenge 참가 경험 또는 상위 입상 경험이 있으신 분\"\n  ]\n}\n\nCheck formatting: JSON with double quotes. Ensure no trailing commas. Provide only JSON."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 1525,
#     "completion_tokens": 800,
#     "total_tokens": 2325
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "국내/외 정규대학(학사) 재학생 또는 기졸업자",
#     "인턴십 기간(약 3개월) 동안 Full-Time 근무가 가능하신 분",
#     "Multimodal Language Model (LLaVA, Qwen VL, DeepSeek VL)에 대한 기본적인 지식 및 학습 과정에 대한 이해를 갖추신 분",
#     "각 학습 단계별 Multimodal LLM 데이터의 특성, 종류에 대한 이해 및 신규 데이터 디자인 능력을 갖추신 분",
#     "Python 활용 능력을 갖추신 분"
#   ],
#   "우대사항": [
#     "Model Driven Data Filtering & Curation 지식이나 경험 이 있으신 분",
#     "최소 1개월 이상 소요된, 팀 프로젝트를 성공적으로 완료한 경험 이 있으신 분",
#     "LLM or Multimodal LLM 관련 Top Tier 논문 작성 경험 이 있으신 분",
#     "Challenge 참가 경험 또는 상위 입상 경험이 있으신 분"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (6/113): https://www.lgresearch.ai/careers/view?seq=253
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-605",
#   "object": "chat.completion",
#   "created": 1756727462,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"논리적 사고력 및 체계적인 문서 작성 능력\",\n    \"꼼꼼하고 책임감 있는 업무 태도\",\n    \"한글 및 영어로 질의하고 응답을 이해·분석할 수 있는 언어 능력\",\n    \"테스트 결과에 대한 정량/정성적 분석 역량\",\n    \"원활한 협업 및 커뮤니케이션 능력\",\n    \"전공 무관 (컴퓨터공학, 산업공학, 인공지능 등 관련 전공 우대)\"\n  ],\n  \"우대사항\": [\n    \"원어민 수준의 영어 읽기 및 글쓰기 능력\",\n    \"LLM 기반 AI 또는 Prompt Engineering 관련 이해\",\n    \"Python 등 간단한 스크립트 작성 능력\",\n    \"데이터 분석/시각화 툴 경험 (Excel, Pandas 등)\",\n    \"CI/CD 파이프라인 또는 테스트 자동화 도구 사용 경험\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting is for \"NLP Quality Engineering Internship\" (Language Lab). The relevant section: \"지원자격\" maybe. Let's locate.\n\nScrolling: There's a section \"지원자격\" but in Korean it's \"지원자격\" or \"자격요건\". In the text: \"지원자격 논리적 사고력 및 체계적인 문서 작성 능력 꼼꼼하고 책임감 있는 업무 태도 한글 및 영어로 질의하고 응답을 이해·분석할 수 있는 언어 능력 테스트 결과에 대한 정량/정성적 분석 역량 원활한 협업 및 커뮤니케이션 능력 전공 무관 (컴퓨터공학, 산업공학, 인공지능 등 관련 전공 우대) *우대사항 원어민 수준의 영어 읽기 및 글쓰기 능력 LLM 기반 AI 또는 Prompt Engineering 관련 이해 Python 등 간단한 스크립트 작성 능력 데이터 분석/시각화 툴 경험 (Excel, Pandas 등) CI/CD 파이프라인 또는 테스트 자동화 도구 사용 경험 전형절차...\"\n\nSo '자격요건' list includes: 논리적 사고력 및 체계적인 문서 작성 능력, 꼼꼼하고 책임감 있는 업무 태도, 한글 및 영어로 질의하고 응답을 이해·분석할 수 있는 언어 능력, 테스트 결과에 대한 정량/정성적 분석 역량, 원활한 협업 및 커뮤니케이션 능력, 전공 무관 (컴퓨터공학, 산업공학, 인공지능 등 관련 전공 우대). The bullet \"*우대사항\" is separate.\n\nThus we need to produce JSON:\n\n{\n  \"자격요건\": [\n    \"논리적 사고력 및 체계적인 문서 작성 능력\",\n    \"꼼꼼하고 책임감 있는 업무 태도\",\n    \"한글 및 영어로 질의하고 응답을 이해·분석할 수 있는 언어 능력\",\n    \"테스트 결과에 대한 정량/정성적 분석 역량\",\n    \"원활한 협업 및 커뮤니케이션 능력\",\n    \"전공 무관 (컴퓨터공학, 산업공학, 인공지능 등 관련 전공 우대)\"\n  ],\n  \"우대사항\": [\n    \"원어민 수준의 영어 읽기 및 글쓰기 능력\",\n    \"LLM 기반 AI 또는 Prompt Engineering 관련 이해\",\n    \"Python 등 간단한 스크립트 작성 능력\",\n    \"데이터 분석/시각화 툴 경험 (Excel, Pandas 등)\",\n    \"CI/CD 파이프라인 또는 테스트 자동화 도구 사용 경험\"\n  ]\n}\n\nCheck if any other '자격요건' earlier? There's also \"지원서 작성하기\" but not relevant. The '자격요건' section is indeed the one above. So produce JSON accordingly."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 1899,
#     "completion_tokens": 865,
#     "total_tokens": 2764
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "논리적 사고력 및 체계적인 문서 작성 능력",
#     "꼼꼼하고 책임감 있는 업무 태도",
#     "한글 및 영어로 질의하고 응답을 이해·분석할 수 있는 언어 능력",
#     "테스트 결과에 대한 정량/정성적 분석 역량",
#     "원활한 협업 및 커뮤니케이션 능력",
#     "전공 무관 (컴퓨터공학, 산업공학, 인공지능 등 관련 전공 우대)"
#   ],
#   "우대사항": [
#     "원어민 수준의 영어 읽기 및 글쓰기 능력",
#     "LLM 기반 AI 또는 Prompt Engineering 관련 이해",
#     "Python 등 간단한 스크립트 작성 능력",
#     "데이터 분석/시각화 툴 경험 (Excel, Pandas 등)",
#     "CI/CD 파이프라인 또는 테스트 자동화 도구 사용 경험"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (7/113): https://career.doosan.com/dsp/sa/RecList.jsp?REC_ID=1000353021&mode=goDetail
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-712",
#   "object": "chat.completion",
#   "created": 1756727496,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"AI를 위한 시맨틱/온톨로지 기반 데이터 분석 및 유즈케이스 구현 프로젝트 리딩 경험\",\n    \"다양한 데이터 관리 기술 및 플랫폼에 대한 풍부한 지식과 경험 (Knowledge Graph, Embedding DB, meta data 등)\",\n    \"데이터 원천 식별, 통합, 정제, 모델링, 카탈로깅, 시각화 등 데이터 분석 End-to-End 라이프사이클 프로세스 경험\",\n    \"논리적 문제 해결 능력 및 커뮤니케이션 능력\"\n  ],\n  \"우대사항\": [\n    \"클라우드 기반 데이터 플랫폼 및 Data Lake/Fabric/Mesh 구현 경험\",\n    \"Global Big Tech 또는 국내 리딩 Digital Natives 기업의 data architect/enginner 업무 경험\",\n    \"제조 산업 비즈니스와 프로세스에 대한 깊은 이해와 업무 경험\",\n    \"데이터, 클라우드 관련 자격증 보유\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting includes a section labeled \"자격요건 [Qualification]\" and \"우대 사항\". We need to list each bullet point as separate strings.\n\nLet's parse:\n\n자격요건 [Qualification] bullet list:\n\n- AI를 위한 시맨틱/온톨로지 기반 데이터 분석 및 유즈케이스 구현 프로젝트 리딩 경험\n- 다양한 데이터 관리 기술 및 플랫폼에 대한 풍부한 지식과 경험 (Knowledge Graph, Embedding DB, meta data 등)\n- 데이터 원천 식별, 통합, 정제, 모델링, 카탈로깅, 시각화 등 데이터 분석 End-to-End 라이프사이클 프로세스 경험\n- 논리적 문제 해결 능력 및 커뮤니케이션 능력\n\n우대 사항 bullet list:\n\n- 클라우드 기반 데이터 플랫폼 및 Data Lake/Fabric/Mesh 구현 경험\n- Global Big Tech 또는 국내 리딩 Digital Natives 기업의 data architect/enginner 업무 경험\n- 제조 산업 비즈니스와 프로세스에 대한 깊은 이해와 업무 경험\n- 데이터, 클라우드 관련 자격증 보유\n\nWe need to output JSON with keys \"자격요건\" and \"우대사항\" each containing array of strings.\n\nMake sure to preserve Korean text exactly. Also note that \"enginner\" is spelled incorrectly but we keep as is.\n\nReturn JSON only."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 1097,
#     "completion_tokens": 532,
#     "total_tokens": 1629
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "AI를 위한 시맨틱/온톨로지 기반 데이터 분석 및 유즈케이스 구현 프로젝트 리딩 경험",
#     "다양한 데이터 관리 기술 및 플랫폼에 대한 풍부한 지식과 경험 (Knowledge Graph, Embedding DB, meta data 등)",
#     "데이터 원천 식별, 통합, 정제, 모델링, 카탈로깅, 시각화 등 데이터 분석 End-to-End 라이프사이클 프로세스 경험",
#     "논리적 문제 해결 능력 및 커뮤니케이션 능력"
#   ],
#   "우대사항": [
#     "클라우드 기반 데이터 플랫폼 및 Data Lake/Fabric/Mesh 구현 경험",
#     "Global Big Tech 또는 국내 리딩 Digital Natives 기업의 data architect/enginner 업무 경험",
#     "제조 산업 비즈니스와 프로세스에 대한 깊은 이해와 업무 경험",
#     "데이터, 클라우드 관련 자격증 보유"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (8/113): https://recruit.cj.net/recruit/ko/recruit/recruit/bestDetail.fo?zz_jo_num=J20250826034037
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-152",
#   "object": "chat.completion",
#   "created": 1756727558,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"4년제 이공계열 대학교 학사 이상 (컴퓨터공학, 산업공학 등 유관전공)\",\n    \"DW/빅데이터 정보계 분석 데이터 설계 경험\",\n    \"Python, SQL, PL/SQL 활용한 데이터 파이프라인 구축 경험\",\n    \"ETL Tool 이용한 데이터 Migration 경험\",\n    \"대용량 데이터 취급 및 DB 성능 개선 경험자\",\n    \"데이터 영역에서의 기술적 네트워크 및 유관 업무 수행 경험\"\n  ],\n  \"우대사항\": [\n    \"분석언어 (R/Python/SQL/NoSQL) 사용 역량 및 관련 자격증 보유자\",\n    \"SQLD, SQLP 자격증 보유자\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting includes a section:\n\n\"자격 - 4년제 이공계열 대학교 학사 이상 (컴퓨터공학, 산업공학 등 유관전공) - DW/빅데이터 정보계 분석 데이터 설계 경험 - Python, SQL, PL/SQL 활용한 데이터 파이프라인 구축 경험 - ETL Tool 이용한 데이터 Migration 경험 - 대용량 데이터 취급 및 DB 성능 개선 경험자 - 데이터 영역에서의 기술적 네트워크 및 유관 업무 수행 경험\"\n\nThen \"우대사항 - 분석언어 (R/Python/SQL/NoSQL) 사용 역량 및 관련 자격증 보유자 - SQLD, SQLP 자격증 보유자\"\n\nAlso earlier there is \"자격요건\" heading? The text shows \"자격 - 4년제...\" but the heading is \"자격\". The user wants '자격요건' and '우대사항'. So we should list the items under each.\n\nThus:\n\n자격요건:\n- 4년제 이공계열 대학교 학사 이상 (컴퓨터공학, 산업공학 등 유관전공)\n- DW/빅데이터 정보계 분석 데이터 설계 경험\n- Python, SQL, PL/SQL 활용한 데이터 파이프라인 구축 경험\n- ETL Tool 이용한 데이터 Migration 경험\n- 대용량 데이터 취급 및 DB 성능 개선 경험자\n- 데이터 영역에서의 기술적 네트워크 및 유관 업무 수행 경험\n\n우대사항:\n- 분석언어 (R/Python/SQL/NoSQL) 사용 역량 및 관련 자격증 보유자\n- SQLD, SQLP 자격증 보유자\n\nWe need JSON format exactly as specified. Ensure no extra keys. Provide empty lists if none. But we have lists.\n\nReturn JSON."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 3654,
#     "completion_tokens": 593,
#     "total_tokens": 4247
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "4년제 이공계열 대학교 학사 이상 (컴퓨터공학, 산업공학 등 유관전공)",
#     "DW/빅데이터 정보계 분석 데이터 설계 경험",
#     "Python, SQL, PL/SQL 활용한 데이터 파이프라인 구축 경험",
#     "ETL Tool 이용한 데이터 Migration 경험",
#     "대용량 데이터 취급 및 DB 성능 개선 경험자",
#     "데이터 영역에서의 기술적 네트워크 및 유관 업무 수행 경험"
#   ],
#   "우대사항": [
#     "분석언어 (R/Python/SQL/NoSQL) 사용 역량 및 관련 자격증 보유자",
#     "SQLD, SQLP 자격증 보유자"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (9/113): https://careers.upstage.ai//o/ai-agent-engineer
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-47",
#   "object": "chat.completion",
#   "created": 1756727632,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"AI 및 Machine Learning에 대한 이해 — 특히 NLP (LLM), CV 분야의 지식 보유\",\n    \"Agentic AI에 대한 이해\",\n    \"LLM을 사용한 프로젝트 수행 경험: 문제 정의부터 모델 설계, 평가, 최적화 등 전 과정을 주도해 본 경험 (정규직)\",\n    \"LLM을 사용한 실제 제품을 개발해본 경험\"\n  ],\n  \"우대사항\": [\n    \"최신 LLM 관련 기술들을 기반으로 한 Agent 시스템 설계 및 구현 경험\",\n    \"Chain-of-Thought, Multi-step Reasoning 등을 활용한 Complex Reasoning 파이프라인 설계 경험\",\n    \"LangChain, LangGraph 등 최신 Agentic Workflow 프레임워크 경험자\",\n    \"Retrieval-Augmented Generation (RAG), Tool Use, Function Calling 등을 활용한 파이프라인 설계 및 튜닝 경험\",\n    \"주요 국제 AI 학회에 제1저자 또는 교신저자로 논문 발표 경험 (ICLR, NeurIPS, ICML, EMNLP, ACL, NAACL, CVPR, ICCV, ECCV, AAAI, IJCAI 등)\",\n    \"국내외 AI 대회(예: Kaggle 등)에서 상위권 입상 경험\",\n    \"영문 기술 문서 작성 및 글로벌 커뮤니케이션 역량 (글로벌 고객 대응 경험이 있다면 더욱 우대)\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting includes a section titled \"Requirements\" with \"필수 사항\" and \"우대 사항\". Those correspond to 자격요건 and 우대사항. We need to list each item.\n\nLet's parse the Requirements section:\n\n\"Requirements 필수 사항 AI 및 Machine Learning에 대한 이해 — 특히 NLP (LLM), CV 분야의 지식 보유 Agentic AI에 대한 이해 LLM을 사용한 프로젝트 수행 경험: 문제 정의부터 모델 설계, 평가, 최적화 등 전 과정을 주도해 본 경험 (정규직) LLM을 사용한 실제 제품을 개발해본 경험 우대 사항 최신 LLM 관련 기술들을 기반으로 한 Agent 시스템 설계 및 구현 경험 Chain-of-Thought, Multi-step Reasoning 등을 활용한 Complex Reasoning 파이프라인 설계 경험 LangChain, LangGraph 등 최신 Agentic Workflow 프레임워크 경험자 Retrieval-Augmented Generation (RAG), Tool Use, Function Calling 등을 활용한 파이프라인 설계 및 튜닝 경험 주요 국제 AI 학회에 제1저자 또는 교신저자로 논문 발표 경험 E.g. ICLR, NeurIPS, ICML, EMNLP, ACL, NAACL, CVPR, ICCV, ECCV, AAAI, IJCAI 등 국내외 AI 대회(예: Kaggle 등)에서 상위권 입상 경험 영문 기술 문서 작성 및 글로벌 커뮤니케이션 역량 (글로벌 고객 대응 경험이 있다면 더욱 우대) *관련 문의사항은 joinstage@upstage.ai로 문의 부탁드립니다.\"\n\nWe need to separate into 자격요건 (필수 사항) and 우대사항 (우대 사항). The items are bullet-like but not formatted. We need to list each requirement as separate string.\n\nLet's list 자격요건:\n\n1. AI 및 Machine Learning에 대한 이해 — 특히 NLP (LLM), CV 분야의 지식 보유\n2. Agentic AI에 대한 이해\n3. LLM을 사용한 프로젝트 수행 경험: 문제 정의부터 모델 설계, 평가, 최적화 등 전 과정을 주도해 본 경험 (정규직)\n4. LLM을 사용한 실제 제품을 개발해본 경험\n\nNow 우대사항:\n\n1. 최신 LLM 관련 기술들을 기반으로 한 Agent 시스템 설계 및 구현 경험\n2. Chain-of-Thought, Multi-step Reasoning 등을 활용한 Complex Reasoning 파이프라인 설계 경험\n3. LangChain, LangGraph 등 최신 Agentic Workflow 프레임워크 경험자\n4. Retrieval-Augmented Generation (RAG), Tool Use, Function Calling 등을 활용한 파이프라인 설계 및 튜닝 경험\n5. 주요 국제 AI 학회에 제1저자 또는 교신저자로 논문 발표 경험 (ICLR, NeurIPS, ICML, EMNLP, ACL, NAACL, CVPR, ICCV, ECCV, AAAI, IJCAI 등)\n6. 국내외 AI 대회(예: Kaggle 등)에서 상위권 입상 경험\n7. 영문 기술 문서 작성 및 글로벌 커뮤니케이션 역량 (글로벌 고객 대응 경험이 있다면 더욱 우대)\n\nWe should ensure no extra spaces. Provide JSON with arrays.\n\nLet's produce."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 2305,
#     "completion_tokens": 1027,
#     "total_tokens": 3332
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "AI 및 Machine Learning에 대한 이해 — 특히 NLP (LLM), CV 분야의 지식 보유",
#     "Agentic AI에 대한 이해",
#     "LLM을 사용한 프로젝트 수행 경험: 문제 정의부터 모델 설계, 평가, 최적화 등 전 과정을 주도해 본 경험 (정규직)",
#     "LLM을 사용한 실제 제품을 개발해본 경험"
#   ],
#   "우대사항": [
#     "최신 LLM 관련 기술들을 기반으로 한 Agent 시스템 설계 및 구현 경험",
#     "Chain-of-Thought, Multi-step Reasoning 등을 활용한 Complex Reasoning 파이프라인 설계 경험",
#     "LangChain, LangGraph 등 최신 Agentic Workflow 프레임워크 경험자",
#     "Retrieval-Augmented Generation (RAG), Tool Use, Function Calling 등을 활용한 파이프라인 설계 및 튜닝 경험",
#     "주요 국제 AI 학회에 제1저자 또는 교신저자로 논문 발표 경험 (ICLR, NeurIPS, ICML, EMNLP, ACL, NAACL, CVPR, ICCV, ECCV, AAAI, IJCAI 등)",
#     "국내외 AI 대회(예: Kaggle 등)에서 상위권 입상 경험",
#     "영문 기술 문서 작성 및 글로벌 커뮤니케이션 역량 (글로벌 고객 대응 경험이 있다면 더욱 우대)"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (10/113): https://careers.upstage.ai/o/ai-agent-engineer
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-197",
#   "object": "chat.completion",
#   "created": 1756727688,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"AI 및 Machine Learning에 대한 이해 — 특히 NLP (LLM), CV 분야의 지식 보유\",\n    \"Agentic AI에 대한 이해\",\n    \"LLM을 사용한 프로젝트 수행 경험: 문제 정의부터 모델 설계, 평가, 최적화 등 전 과정을 주도해 본 경험 (정규직)\",\n    \"LLM을 사용한 실제 제품을 개발해본 경험\"\n  ],\n  \"우대사항\": [\n    \"최신 LLM 관련 기술들을 기반으로 한 Agent 시스템 설계 및 구현 경험\",\n    \"Chain-of-Thought, Multi-step Reasoning 등을 활용한 Complex Reasoning 파이프라인 설계 경험\",\n    \"LangChain, LangGraph 등 최신 Agentic Workflow 프레임워크 경험자\",\n    \"Retrieval-Augmented Generation (RAG), Tool Use, Function Calling 등을 활용한 파이프라인 설계 및 튜닝 경험\",\n    \"주요 국제 AI 학회에 제1저자 또는 교신저자로 논문 발표 경험 E.g. ICLR, NeurIPS, ICML, EMNLP, ACL, NAACL, CVPR, ICCV, ECCV, AAAI, IJCAI 등\",\n    \"국내외 AI 대회(예: Kaggle 등)에서 상위권 입상 경험\",\n    \"영문 기술 문서 작성 및 글로벌 커뮤니케이션 역량 (글로벌 고객 대응 경험이 있다면 더욱 우대)\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting includes a section titled \"Requirements\" with \"필수 사항\" and \"우대 사항\". Those correspond to 자격요건 and 우대사항. We need to list each item.\n\nLet's parse the Requirements section:\n\n\"Requirements 필수 사항 AI 및 Machine Learning에 대한 이해 — 특히 NLP (LLM), CV 분야의 지식 보유 Agentic AI에 대한 이해 LLM을 사용한 프로젝트 수행 경험: 문제 정의부터 모델 설계, 평가, 최적화 등 전 과정을 주도해 본 경험 (정규직) LLM을 사용한 실제 제품을 개발해본 경험 우대 사항 최신 LLM 관련 기술들을 기반으로 한 Agent 시스템 설계 및 구현 경험 Chain-of-Thought, Multi-step Reasoning 등을 활용한 Complex Reasoning 파이프라인 설계 경험 LangChain, LangGraph 등 최신 Agentic Workflow 프레임워크 경험자 Retrieval-Augmented Generation (RAG), Tool Use, Function Calling 등을 활용한 파이프라인 설계 및 튜닝 경험 주요 국제 AI 학회에 제1저자 또는 교신저자로 논문 발표 경험 E.g. ICLR, NeurIPS, ICML, EMNLP, ACL, NAACL, CVPR, ICCV, ECCV, AAAI, IJCAI 등 국내외 AI 대회(예: Kaggle 등)에서 상위권 입상 경험 영문 기술 문서 작성 및 글로벌 커뮤니케이션 역량 (글로벌 고객 대응 경험이 있다면 더욱 우대)\"\n\nWe need to separate into items. For 자격요건 (필수 사항):\n\n- AI 및 Machine Learning에 대한 이해 — 특히 NLP (LLM), CV 분야의 지식 보유\n- Agentic AI에 대한 이해\n- LLM을 사용한 프로젝트 수행 경험: 문제 정의부터 모델 설계, 평가, 최적화 등 전 과정을 주도해 본 경험 (정규직)\n- LLM을 사용한 실제 제품을 개발해본 경험\n\nPotentially also \"정규직\" is part of the requirement. But we can list as separate items.\n\nFor 우대사항:\n\n- 최신 LLM 관련 기술들을 기반으로 한 Agent 시스템 설계 및 구현 경험\n- Chain-of-Thought, Multi-step Reasoning 등을 활용한 Complex Reasoning 파이프라인 설계 경험\n- LangChain, LangGraph 등 최신 Agentic Workflow 프레임워크 경험자\n- Retrieval-Augmented Generation (RAG), Tool Use, Function Calling 등을 활용한 파이프라인 설계 및 튜닝 경험\n- 주요 국제 AI 학회에 제1저자 또는 교신저자로 논문 발표 경험 E.g. ICLR, NeurIPS, ICML, EMNLP, ACL, NAACL, CVPR, ICCV, ECCV, AAAI, IJCAI 등\n- 국내외 AI 대회(예: Kaggle 등)에서 상위권 입상 경험\n- 영문 기술 문서 작성 및 글로벌 커뮤니케이션 역량 (글로벌 고객 대응 경험이 있다면 더욱 우대)\n\nWe need to output JSON with arrays of strings. Ensure no extra keys. Use Korean strings exactly as extracted. Let's produce.\n\nCheck if any other '자격요건' elsewhere? There's also \"근무 형태 정규직/인턴십(정규직 전환형, 3개월~6개월)\" but that's not requirement. So we stick to above.\n\nReturn JSON."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 2305,
#     "completion_tokens": 1058,
#     "total_tokens": 3363
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "AI 및 Machine Learning에 대한 이해 — 특히 NLP (LLM), CV 분야의 지식 보유",
#     "Agentic AI에 대한 이해",
#     "LLM을 사용한 프로젝트 수행 경험: 문제 정의부터 모델 설계, 평가, 최적화 등 전 과정을 주도해 본 경험 (정규직)",
#     "LLM을 사용한 실제 제품을 개발해본 경험"
#   ],
#   "우대사항": [
#     "최신 LLM 관련 기술들을 기반으로 한 Agent 시스템 설계 및 구현 경험",
#     "Chain-of-Thought, Multi-step Reasoning 등을 활용한 Complex Reasoning 파이프라인 설계 경험",
#     "LangChain, LangGraph 등 최신 Agentic Workflow 프레임워크 경험자",
#     "Retrieval-Augmented Generation (RAG), Tool Use, Function Calling 등을 활용한 파이프라인 설계 및 튜닝 경험",
#     "주요 국제 AI 학회에 제1저자 또는 교신저자로 논문 발표 경험 E.g. ICLR, NeurIPS, ICML, EMNLP, ACL, NAACL, CVPR, ICCV, ECCV, AAAI, IJCAI 등",
#     "국내외 AI 대회(예: Kaggle 등)에서 상위권 입상 경험",
#     "영문 기술 문서 작성 및 글로벌 커뮤니케이션 역량 (글로벌 고객 대응 경험이 있다면 더욱 우대)"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (11/113): https://careers.upstage.ai/o/ai-tech-data-management-internship
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-152",
#   "object": "chat.completion",
#   "created": 1756727757,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"Strongly wanted AI 모델 평가 및 분석 관련 토픽으로 국제 학회에서 출판 기록 (공저자 포함) 또는 ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자)\",\n    \"May helpful AI 모델 평가를 위한 데이터 수집, 생성, 정제등을 수행해 본 경험\",\n    \"Agentic flow (w/ tool use)를 설계 및 개발해본 경험\",\n    \"Failure analysis를 기반으로 데이터를 하나하나 들여다 보고 인사이트를 얻을 수 있는 집중력\",\n    \"논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력\",\n    \"복잡한 데이터 협업 프로토콜 (규칙) 을 정돈할 수 있는 시스템적 사고 능력\",\n    \"레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력\"\n  ],\n  \"우대사항\": [\n    \"LLM을 활용한 제품 개발 또는 운영 경험이 있으신 분\",\n    \"AI 모델링 경험이 있으신 분\",\n    \"컴퓨터공학 지식 (Data Structure & Algorithm, Computer Network, Database, OS 등)을 보유하신 분\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting includes a section \"Requirements\" and \"우대 사항\". The '자격요건' likely corresponds to the \"Requirements\" section. The '우대사항' corresponds to the \"우대 사항\" section. We need to list each bullet as separate strings.\n\nLet's parse the Requirements section:\n\n\"Requirements 필수 사항 Strongly wanted AI 모델 평가 및 분석 관련 토픽으로 국제 학회에서 출판 기록 (공저자 포함) 또는 ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자) May helpful AI 모델 평가를 위한 데이터 수집, 생성, 정제등을 수행해 본 경험 Agentic flow (w/ tool use)를 설계 및 개발해본 경험 Failure analysis를 기반으로 데이터를 하나하나 들여다 보고 인사이트를 얻을 수 있는 집중력 논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력 복잡한 데이터 협업 프로토콜 (규칙) 을 정돈할 수 있는 시스템적 사고 능력 레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력\"\n\nWe need to separate each requirement. The formatting is not bullet but a list separated by spaces. Let's identify each requirement:\n\n1. Strongly wanted AI 모델 평가 및 분석 관련 토픽으로 국제 학회에서 출판 기록 (공저자 포함) 또는 ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자)\n2. May helpful AI 모델 평가를 위한 데이터 수집, 생성, 정제등을 수행해 본 경험\n3. Agentic flow (w/ tool use)를 설계 및 개발해본 경험\n4. Failure analysis를 기반으로 데이터를 하나하나 들여다 보고 인사이트를 얻을 수 있는 집중력\n5. 논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력\n6. 복잡한 데이터 협업 프로토콜 (규칙) 을 정돈할 수 있는 시스템적 사고 능력\n7. 레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력\n\nBut the text \"May helpful\" seems like a typo: \"May helpful\" maybe \"May helpful\" but we treat as part of requirement. Actually \"May helpful\" might be \"May helpful\" but we can keep as is.\n\nNow 우대 사항 section:\n\n\"우대 사항 LLM을 활용한 제품 개발 또는 운영 경험이 있으신 분 AI 모델링 경험이 있으신 분 컴퓨터공학 지식 (Data Structure & Algorithm, Computer Network, Database, OS 등)을 보유하신 분\"\n\nSo list:\n\n1. LLM을 활용한 제품 개발 또는 운영 경험이 있으신 분\n2. AI 모델링 경험이 있으신 분\n3. 컴퓨터공학 지식 (Data Structure & Algorithm, Computer Network, Database, OS 등)을 보유하신 분\n\nNow produce JSON:\n\n{\n  \"자격요건\": [...],\n  \"우대사항\": [...]\n}\n\nMake sure to use Korean strings exactly as extracted. Ensure no extra spaces. Let's produce.\n\n"
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 2173,
#     "completion_tokens": 1008,
#     "total_tokens": 3181
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "Strongly wanted AI 모델 평가 및 분석 관련 토픽으로 국제 학회에서 출판 기록 (공저자 포함) 또는 ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자)",
#     "May helpful AI 모델 평가를 위한 데이터 수집, 생성, 정제등을 수행해 본 경험",
#     "Agentic flow (w/ tool use)를 설계 및 개발해본 경험",
#     "Failure analysis를 기반으로 데이터를 하나하나 들여다 보고 인사이트를 얻을 수 있는 집중력",
#     "논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력",
#     "복잡한 데이터 협업 프로토콜 (규칙) 을 정돈할 수 있는 시스템적 사고 능력",
#     "레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력"
#   ],
#   "우대사항": [
#     "LLM을 활용한 제품 개발 또는 운영 경험이 있으신 분",
#     "AI 모델링 경험이 있으신 분",
#     "컴퓨터공학 지식 (Data Structure & Algorithm, Computer Network, Database, OS 등)을 보유하신 분"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (12/113): https://careers.upstage.ai//o/ai-agentic-engineer-trp
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-259",
#   "object": "chat.completion",
#   "created": 1756727814,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"AI 및 Machine Learning에 대한 이해 — 특히 NLP (LLM), CV 분야의 지식 보유\",\n    \"Agentic AI에 대한 이해\",\n    \"LLM을 사용한 프로젝트 수행 경험: 문제 정의부터 모델 설계, 평가, 최적화 등 전 과정을 주도해 본 경험\"\n  ],\n  \"우대사항\": [\n    \"LLM을 사용한 실제 제품을 개발해본 경험\",\n    \"최신 LLM 관련 기술들을 기반으로 한 Agent 시스템 설계 및 구현 경험\",\n    \"Chain-of-Thought, Multi-step Reasoning 등을 활용한 Complex Reasoning 파이프라인 설계 경험\",\n    \"LangChain, LangGraph 등 최신 Agentic Workflow 프레임워크 경험자\",\n    \"Retrieval-Augmented Generation (RAG), Tool Use, Function Calling 등을 활용한 파이프라인 설계 및 튜닝 경험\",\n    \"주요 국제 AI 학회에 제1저자 또는 교신저자로 논문 발표 경험 (예: ICLR, NeurIPS, ICML, EMNLP, ACL, NAACL, CVPR, ICCV, ECCV, AAAI, IJCAI 등)\",\n    \"국내외 AI 대회(예: Kaggle 등)에서 상위권 입상 경험\",\n    \"영문 기술 문서 작성 및 글로벌 커뮤니케이션 역량 (글로벌 고객 대응 경험이 있다면 더욱 우대)\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting includes a section \"Requirements 필수사항\" and \"우대사항\". The '자격요건' likely corresponds to the 필수사항. Let's list each bullet under 필수사항. They are:\n\n- AI 및 Machine Learning에 대한 이해 — 특히 NLP (LLM), CV 분야의 지식 보유\n- Agentic AI에 대한 이해\n- LLM을 사용한 프로젝트 수행 경험: 문제 정의부터 모델 설계, 평가, 최적화 등 전 과정을 주도해 본 경험\n\nAlso maybe \"전문연구요원 신규편입 & 전직\" but that's not a requirement. The 필수사항 section is the requirements.\n\nNow 우대사항 list:\n\n- LLM을 사용한 실제 제품을 개발해본 경험\n- 최신 LLM 관련 기술들을 기반으로 한 Agent 시스템 설계 및 구현 경험\n- Chain-of-Thought, Multi-step Reasoning 등을 활용한 Complex Reasoning 파이프라인 설계 경험\n- LangChain, LangGraph 등 최신 Agentic Workflow 프레임워크 경험자\n- Retrieval-Augmented Generation (RAG), Tool Use, Function Calling 등을 활용한 파이프라인 설계 및 튜닝 경험\n- 주요 국제 AI 학회에 제1저자 또는 교신저자로 논문 발표 경험 E.g. ICLR, NeurIPS, ICML, EMNLP, ACL, NAACL, CVPR, ICCV, ECCV, AAAI, IJCAI 등 국내외 AI 대회(예: Kaggle 등)에서 상위권 입상 경험\n- 영문 기술 문서 작성 및 글로벌 커뮤니케이션 역량 (글로벌 고객 대응 경험이 있다면 더욱 우대)\n\nWe need to output JSON with arrays of strings. Ensure no extra keys. Provide exactly as specified. Let's produce."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 2387,
#     "completion_tokens": 717,
#     "total_tokens": 3104
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "AI 및 Machine Learning에 대한 이해 — 특히 NLP (LLM), CV 분야의 지식 보유",
#     "Agentic AI에 대한 이해",
#     "LLM을 사용한 프로젝트 수행 경험: 문제 정의부터 모델 설계, 평가, 최적화 등 전 과정을 주도해 본 경험"
#   ],
#   "우대사항": [
#     "LLM을 사용한 실제 제품을 개발해본 경험",
#     "최신 LLM 관련 기술들을 기반으로 한 Agent 시스템 설계 및 구현 경험",
#     "Chain-of-Thought, Multi-step Reasoning 등을 활용한 Complex Reasoning 파이프라인 설계 경험",
#     "LangChain, LangGraph 등 최신 Agentic Workflow 프레임워크 경험자",
#     "Retrieval-Augmented Generation (RAG), Tool Use, Function Calling 등을 활용한 파이프라인 설계 및 튜닝 경험",
#     "주요 국제 AI 학회에 제1저자 또는 교신저자로 논문 발표 경험 (예: ICLR, NeurIPS, ICML, EMNLP, ACL, NAACL, CVPR, ICCV, ECCV, AAAI, IJCAI 등)",
#     "국내외 AI 대회(예: Kaggle 등)에서 상위권 입상 경험",
#     "영문 기술 문서 작성 및 글로벌 커뮤니케이션 역량 (글로벌 고객 대응 경험이 있다면 더욱 우대)"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (13/113): https://careers.upstage.ai//o/wbl-ai-research-engineer-llm-post-training
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-342",
#   "object": "chat.completion",
#   "created": 1756727884,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"LLM post-training/fine-tuning을 수행하여 특정 문제에서 최고 성능을 달성해본 경험\",\n    \"ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자)\",\n    \"LLM Post-training을 위한 데이터 수집, 생성, 정제등을 수행해 본 경험\",\n    \"국제 혹은 국내 AI 대회 (Kaggle 등) 상위권 입상\",\n    \"0.1%의 성능에 민감하여 제한된 자원과 시간에 최적화를 수행할 수 있는 집중력\",\n    \"논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력\",\n    \"레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력\"\n  ],\n  \"우대사항\": [\n    \"AI 관련 연구 또는 프로덕트 개발을 리딩한 경험\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting is in Korean but includes English. The 'Requirements' section lists bullet points. We need to interpret which are '자격요건' (qualifications) and which are '우대사항' (preferential). The Korean text: \"Requirements Strongly wanted LLM post-training/fine-tuning을 수행하여 특정 문제에서 최고 성능을 달성해본 경험 ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자) May be helpful AI 관련 연구 또는 프로덕트 개발을 리딩한 경험 LLM Post-training을 위한 데이터 수집, 생성, 정제등을 수행해 본 경험 국제 혹은 국내 AI 대회 (Kaggle 등) 상위권 입상 0.1%의 성능에 민감하여 제한된 자원과 시간에 최적화를 수행할 수 있는 집중력 논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력 레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력\"\n\nWe need to categorize. Usually '자격요건' are required qualifications, '우대사항' are preferred. The text says \"Requirements Strongly wanted\" which might be a mix. The bullet list includes many items. We need to decide which are mandatory and which are optional. The phrase \"Strongly wanted\" suggests these are desired but maybe not mandatory. But the instruction: \"자격요건\" and \"우대사항\" from the content. The content may not explicitly label them. We need to infer. The \"Requirements\" section likely includes both. But we can treat all listed items as '자격요건' because they are requirements. But maybe some are optional. The phrase \"May be helpful\" indicates optional. So we can separate: items with \"May be helpful\" as 우대사항. Also \"Strongly wanted\" maybe still requirement. But we can interpret \"Strongly wanted\" as requirement. So we list all items except the one with \"May be helpful\" as 자격요건. The \"May be helpful\" bullet: \"AI 관련 연구 또는 프로덕트 개발을 리딩한 경험\" is optional. So that goes to 우대사항.\n\nAlso maybe \"International or domestic AI competition (Kaggle 등) 상위권 입상\" is a requirement? It's a bullet. Might be requirement. But we can treat all as requirement except the optional one.\n\nThus:\n\n자격요건:\n- LLM post-training/fine-tuning을 수행하여 특정 문제에서 최고 성능을 달성해본 경험\n- ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자)\n- LLM Post-training을 위한 데이터 수집, 생성, 정제등을 수행해 본 경험\n- 국제 혹은 국내 AI 대회 (Kaggle 등) 상위권 입상\n- 0.1%의 성능에 민감하여 제한된 자원과 시간에 최적화를 수행할 수 있는 집중력\n- 논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력\n- 레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력\n\n우대사항:\n- AI 관련 연구 또는 프로덕트 개발을 리딩한 경험\n\nCheck if any other optional. The phrase \"May be helpful\" only appears once. So that's it.\n\nReturn JSON."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 2195,
#     "completion_tokens": 1015,
#     "total_tokens": 3210
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "LLM post-training/fine-tuning을 수행하여 특정 문제에서 최고 성능을 달성해본 경험",
#     "ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자)",
#     "LLM Post-training을 위한 데이터 수집, 생성, 정제등을 수행해 본 경험",
#     "국제 혹은 국내 AI 대회 (Kaggle 등) 상위권 입상",
#     "0.1%의 성능에 민감하여 제한된 자원과 시간에 최적화를 수행할 수 있는 집중력",
#     "논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력",
#     "레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력"
#   ],
#   "우대사항": [
#     "AI 관련 연구 또는 프로덕트 개발을 리딩한 경험"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (14/113): https://careers.upstage.ai/o/wbl-ai-research-engineer-llm-post-training
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-106",
#   "object": "chat.completion",
#   "created": 1756727964,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"LLM post-training/fine-tuning을 수행하여 특정 문제에서 최고 성능을 달성해본 경험\",\n    \"ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자)\",\n    \"LLM Post-training을 위한 데이터 수집, 생성, 정제 등을 수행해 본 경험\",\n    \"국제 혹은 국내 AI 대회 (Kaggle 등) 상위권 입상\",\n    \"0.1%의 성능에 민감하여 제한된 자원과 시간에 최적화를 수행할 수 있는 집중력\",\n    \"논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력\",\n    \"레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력\"\n  ],\n  \"우대사항\": [\n    \"AI 관련 연구 또는 프로덕트 개발을 리딩한 경험\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting is in Korean but includes English. The 'Requirements' section lists bullet points. We need to interpret which are '자격요건' (qualifications) and which are '우대사항' (preferential). The Korean text: \"Requirements Strongly wanted LLM post-training/fine-tuning을 수행하여 특정 문제에서 최고 성능을 달성해본 경험 ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자) May be helpful AI 관련 연구 또는 프로덕트 개발을 리딩한 경험 LLM Post-training을 위한 데이터 수집, 생성, 정제등을 수행해 본 경험 국제 혹은 국내 AI 대회 (Kaggle 등) 상위권 입상 0.1%의 성능에 민감하여 제한된 자원과 시간에 최적화를 수행할 수 있는 집중력 논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력 레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력\"\n\nWe need to categorize. Usually '자격요건' are required qualifications, '우대사항' are preferred. The text says \"Requirements Strongly wanted\" which might be a mix. The bullet list includes many items. We need to decide which are mandatory and which are optional. The phrase \"Strongly wanted\" suggests these are desired but maybe not mandatory. But the instruction: \"자격요건\" and \"우대사항\" from the content. The content may not explicitly label them. We need to infer. The \"Requirements\" section likely includes both. But we can treat all listed items as '자격요건' because they are requirements. But maybe some are optional. The phrase \"May be helpful\" indicates optional. So we can separate: items with \"May be helpful\" as 우대사항. Also \"Strongly wanted\" maybe still requirement. But we can interpret \"Strongly wanted\" as requirement. So:\n\n자격요건:\n- LLM post-training/fine-tuning을 수행하여 특정 문제에서 최고 성능을 달성해본 경험\n- ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자)\n- AI 관련 연구 또는 프로덕트 개발을 리딩한 경험\n- LLM Post-training을 위한 데이터 수집, 생성, 정제등을 수행해 본 경험\n- 국제 혹은 국내 AI 대회 (Kaggle 등) 상위권 입상\n- 0.1%의 성능에 민감하여 제한된 자원과 시간에 최적화를 수행할 수 있는 집중력\n- 논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력\n- 레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력\n\n우대사항:\n- May be helpful: AI 관련 연구 또는 프로덕트 개발을 리딩한 경험? Wait that is already in 자격요건. Actually \"May be helpful\" appears before \"AI 관련 연구 또는 프로덕트 개발을 리딩한 경험\". So maybe that bullet is optional. But we already included it. Let's parse: The list: \"Strongly wanted LLM post-training/fine-tuning을 수행하여 특정 문제에서 최고 성능을 달성해본 경험 ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자) May be helpful AI 관련 연구 또는 프로덕트 개발을 리딩한 경험 LLM Post-training을 위한 데이터 수집, 생성, 정제등을 수행해 본 경험 국제 혹은 국내 AI 대회 (Kaggle 등) 상위권 입상 0.1%의 성능에 민감하여 제한된 자원과 시간에 최적화를 수행할 수 있는 집중력 논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력 레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력\"\n\nIt seems \"May be helpful\" is a separate line, maybe preceding \"AI 관련 연구 또는 프로덕트 개발을 리딩한 경험\". So \"AI 관련 연구 또는 프로덕트 개발을 리딩한 경험\" is optional. But we already included it as requirement. So we need to adjust: The bullet \"AI 관련 연구 또는 프로덕트 개발을 리딩한 경험\" is under \"May be helpful\" so it's 우대사항. So we should not include it in 자격요건. So adjust:\n\n자격요건 list excludes that bullet. So:\n\n자격요건:\n- LLM post-training/fine-tuning을 수행하여 특정 문제에서 최고 성능을 달성해본 경험\n- ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자)\n- LLM Post-training을 위한 데이터 수집, 생성, 정제등을 수행해 본 경험\n- 국제 혹은 국내 AI 대회 (Kaggle 등) 상위권 입상\n- 0.1%의 성능에 민감하여 제한된 자원과 시간에 최적화를 수행할 수 있는 집중력\n- 논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력\n- 레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력\n\n우대사항:\n- AI 관련 연구 또는 프로덕트 개발을 리딩한 경험\n\nAlso maybe \"May be helpful\" indicates optional. So we include that bullet only. Good.\n\nReturn JSON."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 2195,
#     "completion_tokens": 1497,
#     "total_tokens": 3692
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "LLM post-training/fine-tuning을 수행하여 특정 문제에서 최고 성능을 달성해본 경험",
#     "ML과 NLP 토픽으로 국제 학회에서 출판 기록 (1저자 혹은 교신저자)",
#     "LLM Post-training을 위한 데이터 수집, 생성, 정제 등을 수행해 본 경험",
#     "국제 혹은 국내 AI 대회 (Kaggle 등) 상위권 입상",
#     "0.1%의 성능에 민감하여 제한된 자원과 시간에 최적화를 수행할 수 있는 집중력",
#     "논리적인 사고실험을 수행하고 가설/검증의 방식으로 실험 설계 및 결과를 도출할 수 있는 사고력",
#     "레슨런을 효과적이고 효율적으로 전파하고 논의할 수 있는 의사소통 능력"
#   ],
#   "우대사항": [
#     "AI 관련 연구 또는 프로덕트 개발을 리딩한 경험"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (15/113): https://recruit.kreamcorp.com/rcrt/view.do?annoId=30003834&lang=ko
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-681",
#   "object": "chat.completion",
#   "created": 1756728001,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"계약기간(약 3개월) 동안 Full-Time 근무 가능\",\n    \"채용 전형 절차 별 일정에 참여 가능\",\n    \"Python, SQL 사용에 능숙하고 데이터를 신속/정확하게 도출하는 능력\",\n    \"엑셀/PPT 활용 스킬\",\n    \"꼼꼼함을 기반으로 한 정리 능력\"\n  ],\n  \"우대사항\": [\n    \"이커머스 산업에 대한 이해도 보유 및 관련 데이터 분석 경험 보유\",\n    \"통계 분석에 익숙함\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting includes a section \"필요 역량\" and \"우대 사항\". The '자격요건' likely refers to required qualifications. The posting lists \"필요 역량\" bullet points: \"계약기간 (약 3개월) 동안 Full-Time 근무 가능하신 분 - 채용 전형 절차 별 일정에 참여 가능하신 분 [입과 예정일 : 2025년 9월 22일] - Python, SQL 사용에 능숙하고 데이터를 신속/정확하게 도출하는 능력 - 엑셀/PPT 활용 스킬 - 꼼꼼함을 기반으로 한 정리 능력\". These are required. So list them.\n\n'우대사항' section: \"이커머스 산업에 대한 이해도 보유 및 관련 데이터 분석 경험을 보유하신 분 - 통계 분석에 익숙하신 분\". Also mention \"국가유공자 및 장애인 등 취업보호대상자는 관계법령에 따라 우대합니다.\" But that is a general policy, not a specific skill. The question: \"자격요건\" and \"우대사항\" from the content. So we include the bullet points under each.\n\nThus JSON:\n\n{\n  \"자격요건\": [\n    \"계약기간(약 3개월) 동안 Full-Time 근무 가능\",\n    \"채용 전형 절차 별 일정에 참여 가능\",\n    \"Python, SQL 사용에 능숙하고 데이터를 신속/정확하게 도출하는 능력\",\n    \"엑셀/PPT 활용 스킬\",\n    \"꼼꼼함을 기반으로 한 정리 능력\"\n  ],\n  \"우대사항\": [\n    \"이커머스 산업에 대한 이해도 보유 및 관련 데이터 분석 경험 보유\",\n    \"통계 분석에 익숙함\"\n  ]\n}\n\nCheck if any other '자격요건' like \"입과 예정일: 2025년 9월 22일\" is not a requirement. It's just schedule. So fine.\n\nReturn JSON only."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
# ...
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 1534,
#     "completion_tokens": 524,
#     "total_tokens": 2058
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "Bachelor’s degree or above",
#     "At least 1-2 years of professional work experience, preferably in data labelling, QA, quality improvement",
#     "Proficient level of Korean and English (reading, writing, listening, speaking) for daily communication. Communication skills between cross-functional internal teams and external vendors",
#     "Project management skills, familiarity with RCA and data analysis",
#     "Knowledge about search engines, familiarity with social media platforms"
#   ],
#   "우대사항": [
#     "Overseas work/training experience or in a multicultural/multilingual environment is a plus",
#     "Deep understanding of search engine mechanisms, AI, and machine learning",
#     "Knowledge of the TikTok App, functions, and services especially related to Ads",
#     "Familiar with common office software"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (48/113): https://hyundaimovex.careerlink.kr/jobs/RC20240119002824
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (49/113): https://career.hyperconnect.com/job/edf748a7-a883-4fef-8112-8cbfba14afa3
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-262",
#   "object": "chat.completion",
#   "created": 1756729885,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"AI/ML에 대한 기본 지식과 적어도 한 개 이상의 특정 도메인에 대한 깊이 있는 지식을 갖추고, 관련 프로젝트 경험이 있으신 분\",\n    \"Exploratory Data Analysis(EDA)를 통해, 데이터의 통계적 특성과 패턴을 발견하고 이를 ML 모델에 반영하실 수 있는 분\",\n    \"공개된 벤치마크 데이터 셋을 이용해 모델의 테스트 성능을 올리기 위해 여러 가지 모델링을 해본 경험이 있으신 분\",\n    \"구현체가 공개되지 않은 논문을 읽고, 빠르고 정확하게 구현할 수 있는 구현 역량을 갖추신 분\",\n    \"Tensorflow, PyTorch, JAX 등 오픈소스 프레임워크 및 전반적인 파이썬 개발에 능숙하신 분\",\n    \"ML 모델 학습 및 서비스 배포에 필요한 엔지니어링 역량을 갖추신 분\",\n    \"AI 기술의 서비스화에 관심이 많으신 분\",\n    \"학위/국적 무관, 영어로 기초적인 의사소통이 가능하고, 한국어로 원활한 의사소통이 가능한 분\"\n  ],\n  \"우대사항\": [\n    \"AI/ML 도메인 전반에 대한 이해를 갖추신 분\",\n    \"ML 관련 탑티어 학회 및 저널(NeurIPS, ICLR, ICML, CVPR, ICCV/ECCV, KDD, …) 게재 실적 혹은 AI 관련 대회 수상 실적이 있으신 분\",\n    \"ML 관련 오픈 소스 개발에 참여해 본 경험이 있으신 분\",\n    \"ML 워크플로우의 자동화 경험이 있으신 분(예: AutoML, hyperparameter optimization, 데이터 및 학습 파이프라인 구성 등)\",\n    \"클라이언트(Android, iOS), 백엔드를 포함해 AI/ML 분야 외 프로젝트 개발 경험이 있으신 분\",\n    \"실제 서비스에 AI 기술을 통합하고 주요 지표를 유의미하게 향상시켜 본 경험이 있으신 분\",\n    \"A/B 테스트 실험 기획 및 타겟 KPI 지표를 정의하고, SQL기반 데이터 분석을 진행한 경험이 있으신 분\",\n    \"영어로 비즈니스 의사소통이 가능하신 분\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting is in Korean. The sections likely labeled \"Requirements\" and \"Preferred Qualifications\". The Korean terms: \"Requirements\" is \"Requirements\" but in Korean maybe \"Requirements\" is \"Requirements\" but the Korean translation might be \"Requirements\" or \"자격요건\". The posting uses \"Requirements\" heading. Then \"Preferred Qualifications\" heading. So we need to parse those sections.\n\nWe need to list each bullet point as separate string. The bullet points are in the Requirements section:\n\n- AI/ML에 대한 기본 지식과 적어도 한 개 이상의 특정 도메인에 대한 깊이 있는 지식을 갖추고, 관련 프로젝트 경험이 있으신 분\n- Exploratory Data Analysis(EDA)를 통해, 데이터의 통계적 특성과 패턴을 발견하고 이를 ML 모델에 반영하실 수 있는 분\n- 공개된 벤치마크 데이터 셋을 이용해 모델의 테스트 성능을 올리기 위해 여러 가지 모델링을 해본 경험이 있으신 분\n- 구현체가 공개되지 않은 논문을 읽고, 빠르고 정확하게 구현할 수 있는 구현 역량을 갖추신 분\n- Tensorflow, PyTorch, JAX 등 오픈소스 프레임워크 및 전반적인 파이썬 개발에 능숙하신 분\n- ML 모델 학습 및 서비스 배포에 필요한 엔지니어링 역량을 갖추신 분\n- AI 기술의 서비스화에 관심이 많으신 분\n- 학위/국적 무관, 영어로 기초적인 의사소통이 가능하고, 한국어로 원활한 의사소통이 가능한 분\n\nAlso maybe \"Requirements\" includes \"학위/국적 무관\" etc. So we list those.\n\nNow \"Preferred Qualifications\" section:\n\n- AI/ML 도메인 전반에 대한 이해를 갖추신 분\n- ML 관련 탑티어 학회 및 저널(NeurIPS, ICLR, ICML, CVPR, ICCV/ECCV, KDD, …) 게재 실적 혹은 AI 관련 대회 수상 실적이 있으신 분\n- ML 관련 오픈 소스 개발에 참여해 본 경험이 있으신 분\n- ML 워크플로우의 자동화 경험이 있으신 분(예: AutoML, hyperparameter optimization, 데이터 및 학습 파이프라인 구성 등)\n- 클라이언트(Android, iOS), 백엔드를 포함해 AI/ML 분야 외 프로젝트 개발 경험이 있으신 분\n- 실제 서비스에 AI 기술을 통합하고 주요 지표를 유의미하게 향상시켜 본 경험이 있으신 분\n- A/B 테스트 실험 기획 및 타겟 KPI 지표를 정의하고, SQL기반 데이터 분석을 진행한 경험이 있으신 분\n- 영어로 비즈니스 의사소통이 가능하신 분\n\nAlso maybe \"Preferred Qualifications\" includes \"AI/ML 도메인 전반에 대한 이해를 갖추신 분\" etc.\n\nWe need to output JSON with keys \"자격요건\" and \"우대사항\" each list of strings.\n\nMake sure to preserve Korean text exactly as in posting. Use same bullet content. Ensure no extra spaces or punctuation differences. The bullet lines may have trailing spaces. We'll copy them.\n\nLet's extract each bullet exactly.\n\nFrom Requirements:\n\n1. AI/ML에 대한 기본 지식과 적어도 한 개 이상의 특정 도메인에 대한 깊이 있는 지식을 갖추고, 관련 프로젝트 경험이 있으신 분\n2. Exploratory Data Analysis(EDA)를 통해, 데이터의 통계적 특성과 패턴을 발견하고 이를 ML 모델에 반영하실 수 있는 분\n3. 공개된 벤치마크 데이터 셋을 이용해 모델의 테스트 성능을 올리기 위해 여러 가지 모델링을 해본 경험이 있으신 분\n4. 구현체가 공개되지 않은 논문을 읽고, 빠르고 정확하게 구현할 수 있는 구현 역량을 갖추신 분\n5. Tensorflow, PyTorch, JAX 등 오픈소스 프레임워크 및 전반적인 파이썬 개발에 능숙하신 분\n6. ML 모델 학습 및 서비스 배포에 필요한 엔지니어링 역량을 갖추신 분\n7. AI 기술의 서비스화에 관심이 많으신 분\n8. 학위/국적 무관, 영어로 기초적인 의사소통이 가능하고, 한국어로 원활한 의사소통이 가능한 분\n\nFrom Preferred Qualifications:\n\n1. AI/ML 도메인 전반에 대한 이해를 갖추신 분\n2. ML 관련 탑티어 학회 및 저널(NeurIPS, ICLR, ICML, CVPR, ICCV/ECCV, KDD, …) 게재 실적 혹은 AI 관련 대회 수상 실적이 있으신 분\n3. ML 관련 오픈 소스 개발에 참여해 본 경험이 있으신 분\n4. ML 워크플로우의 자동화 경험이 있으신 분(예: AutoML, hyperparameter optimization, 데이터 및 학습 파이프라인 구성 등)\n5. 클라이언트(Android, iOS), 백엔드를 포함해 AI/ML 분야 외 프로젝트 개발 경험이 있으신 분\n6. 실제 서비스에 AI 기술을 통합하고 주요 지표를 유의미하게 향상시켜 본 경험이 있으신 분\n7. A/B 테스트 실험 기획 및 타겟 KPI 지표를 정의하고, SQL기반 데이터 분석을 진행한 경험이 있으신 분\n8. 영어로 비즈니스 의사소통이 가능하신 분\n\nCheck if any other bullet lines exist. The posting also has \"학위/국적 무관, 영어로 기초적인 의사소통이 가능하고, 한국어로 원활한 의사소통이 가능한 분\" which is part of Requirements. Good.\n\nNow produce JSON.\n\nMake sure to escape quotes properly. Use double quotes for JSON keys and values. The values are Korean strings. Ensure no trailing spaces. Provide JSON only.\n\nLet's produce."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 2273,
#     "completion_tokens": 1857,
#     "total_tokens": 4130
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "AI/ML에 대한 기본 지식과 적어도 한 개 이상의 특정 도메인에 대한 깊이 있는 지식을 갖추고, 관련 프로젝트 경험이 있으신 분",
#     "Exploratory Data Analysis(EDA)를 통해, 데이터의 통계적 특성과 패턴을 발견하고 이를 ML 모델에 반영하실 수 있는 분",
#     "공개된 벤치마크 데이터 셋을 이용해 모델의 테스트 성능을 올리기 위해 여러 가지 모델링을 해본 경험이 있으신 분",
#     "구현체가 공개되지 않은 논문을 읽고, 빠르고 정확하게 구현할 수 있는 구현 역량을 갖추신 분",
#     "Tensorflow, PyTorch, JAX 등 오픈소스 프레임워크 및 전반적인 파이썬 개발에 능숙하신 분",
#     "ML 모델 학습 및 서비스 배포에 필요한 엔지니어링 역량을 갖추신 분",
#     "AI 기술의 서비스화에 관심이 많으신 분",
#     "학위/국적 무관, 영어로 기초적인 의사소통이 가능하고, 한국어로 원활한 의사소통이 가능한 분"
#   ],
#   "우대사항": [
#     "AI/ML 도메인 전반에 대한 이해를 갖추신 분",
#     "ML 관련 탑티어 학회 및 저널(NeurIPS, ICLR, ICML, CVPR, ICCV/ECCV, KDD, …) 게재 실적 혹은 AI 관련 대회 수상 실적이 있으신 분",
#     "ML 관련 오픈 소스 개발에 참여해 본 경험이 있으신 분",
#     "ML 워크플로우의 자동화 경험이 있으신 분(예: AutoML, hyperparameter optimization, 데이터 및 학습 파이프라인 구성 등)",
#     "클라이언트(Android, iOS), 백엔드를 포함해 AI/ML 분야 외 프로젝트 개발 경험이 있으신 분",
#     "실제 서비스에 AI 기술을 통합하고 주요 지표를 유의미하게 향상시켜 본 경험이 있으신 분",
#     "A/B 테스트 실험 기획 및 타겟 KPI 지표를 정의하고, SQL기반 데이터 분석을 진행한 경험이 있으신 분",
#     "영어로 비즈니스 의사소통이 가능하신 분"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (50/113): https://gmarketcareers.ninehire.site/job_posting/71CiT5ae
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM 전체 응답: {
#   "id": "chatcmpl-753",
#   "object": "chat.completion",
#   "created": 1756729942,
#   "model": "gpt-oss",
#   "system_fingerprint": "fp_ollama",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "{\n  \"자격요건\": [\n    \"G마켓/옥션으로 회원가입이 되어있는 분\",\n    \"해외여행 결격 사유가 없는 분\",\n    \"병역필 또는 면제자\"\n  ],\n  \"우대사항\": [\n    \"국가보훈 대상자와 장애인은 관련 법에 따라 우대합니다\",\n    \"국가유공자 가산점 부여받기 위해 '취업 지원 대상자 증명서' 회사에 제출 필요\"\n  ]\n}",
#         "reasoning": "We need to extract '자격요건' and '우대사항' from the job posting. The posting includes a section titled \"공통요건\" which lists common requirements. That likely corresponds to 자격요건. Also there is mention of 우대: \"국가보훈 대상자와 장애인은 관련 법에 따라 우대합니다\" and \"국가유공자 가산점 부여받기 위해 '취업 지원 대상자 증명서' 회사에 제출 필요\". So 우대사항 likely includes those. Also maybe other 우대사항 not explicitly labeled. Let's parse.\n\nThe posting:\n\n- 공통요건:\n  - G마켓/옥션으로 회원가입이 되어있는 분\n  - 해외여행 결격 사유가 없는 분\n  - 병역필 또는 면제자\n  - 국가보훈 대상자와 장애인은 관련 법에 따라 우대합니다\n  - ** 국가유공자 가산점 부여받기 위해 \"취업 지원 대상자 증명서\" 회사에 제출 필요\n\nSo 자격요건 list: those four bullet points? The last bullet is about 우대? Actually \"국가보훈 대상자와 장애인은 관련 법에 따라 우대합니다\" is a 우대사항. The last bullet about \"국가유공자 가산점 부여받기 위해 '취업 지원 대상자 증명서' 회사에 제출 필요\" is a requirement for national merit persons. That might be a requirement for those persons. But it's more like a requirement for those who want to get extra points. But it's still a requirement. But we can treat it as a requirement for national merit persons. But the instruction: \"자격요건\" and \"우대사항\" separately. So we need to separate.\n\nThus:\n\n자격요건:\n- G마켓/옥션으로 회원가입이 되어있는 분\n- 해외여행 결격 사유가 없는 분\n- 병역필 또는 면제자\n\n우대사항:\n- 국가보훈 대상자와 장애인은 관련 법에 따라 우대합니다\n- 국가유공자 가산점 부여받기 위해 \"취업 지원 대상자 증명서\" 회사에 제출 필요\n\nAlso maybe \"경력 무관\" is a note but not requirement. So we keep only those.\n\nThus JSON:\n\n{\n  \"자격요건\": [\n    \"G마켓/옥션으로 회원가입이 되어있는 분\",\n    \"해외여행 결격 사유가 없는 분\",\n    \"병역필 또는 면제자\"\n  ],\n  \"우대사항\": [\n    \"국가보훈 대상자와 장애인은 관련 법에 따라 우대합니다\",\n    \"국가유공자 가산점 부여받기 위해 '취업 지원 대상자 증명서' 회사에 제출 필요\"\n  ]\n}\n\nCheck if any other 우대사항: The posting says \"국가보훈 대상자와 장애인은 관련 법에 따라 우대합니다\" and \"국가유공자 가산점 부여받기 위해 '취업 지원 대상자 증명서' 회사에 제출 필요\". That's it.\n\nThus output."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 1753,
#     "completion_tokens": 784,
#     "total_tokens": 2537
#   }
# }
#   --- LLM 원본 응답 ---
# {
#   "자격요건": [
#     "G마켓/옥션으로 회원가입이 되어있는 분",
#     "해외여행 결격 사유가 없는 분",
#     "병역필 또는 면제자"
#   ],
#   "우대사항": [
#     "국가보훈 대상자와 장애인은 관련 법에 따라 우대합니다",
#     "국가유공자 가산점 부여받기 위해 '취업 지원 대상자 증명서' 회사에 제출 필요"
#   ]
# }
#   --------------------
#   -> 정보 추출 완료.
# 처리 중 (51/113): https://recruit.cj.net/recruit/ko/recruit/recruit/bestDetail.fo?zz_jo_num=J20250625031041
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM API 호출 오류: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=300)
#   -> 정보 추출 실패.
#
# 작업 완료!
#
# === 2번째 재시도: 64건 ===
# 처리 중 (18/64): https://medtronic.wd1.myworkdayjobs.com/en-US/MedtronicCareers/job/Seoul-Seoul-Korea/Korea-Channel-Data-Analyst--Contract-_R37500?locationCountry=7a5a2aadf9d34086a2bfbfd408bc28da
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (60/64): https://hyundaimovex.careerlink.kr/jobs/RC20240119002824
#   -> 처리할 텍스트 내용이 없습니다.
# 처리 중 (63/64): https://recruit.cj.net/recruit/ko/recruit/recruit/bestDetail.fo?zz_jo_num=J20250625031041
#   -> LLM 호출하여 정보 추출 중...
#   -> LLM API 호출 오류: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=300)
#   -> 정보 추출 실패.
#
# 작업 완료!
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# Cell In[13], line 26
#
#      24     for idx, row in retry_result.iterrows():
#
#      25         mask = result_df["지원 링크"] == row["지원 링크"]
#
# ---> 26         result_df.loc[mask, ["자격요건", "우대사항"]] = row[["자격요건", "우대사항"]].values
#
#      28     attempt += 1
#
#      30 # 최종 결과 분리
#
#
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1162, in Series.__getitem__(self, key)
#
#    1159     key = np.asarray(key, dtype=bool)
#
#    1160     return self._get_rows_with_mask(key)
#
# -> 1162 return self._get_with(key)
#
#
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1203, in Series._get_with(self, key)
#
#    1200         return self.iloc[key]
#
#    1202 # handle the dup indexing case GH#4246
#
# -> 1203 return self.loc[key]
#
#
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
#
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
#
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#
#    1418         raise ValueError("Cannot index with multidimensional key")
#
# -> 1420     return self._getitem_iterable(key, axis=axis)
#
#    1422 # nested tuple slicing
#
#    1423 if is_nested_tuple(key, labels):
#
#
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#
#    1357 self._validate_key(key, axis)
#
#    1359 # A collection of keys
#
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#
#    1361 return self.obj._reindex_with_indexers(
#
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
#    1363 )
#
#
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#
#    1555 ax = self.obj._get_axis(axis)
#
#    1556 axis_name = self.obj._get_axis_name(axis)
#
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#
#    1560 return keyarr, indexer
#
#
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#
#    6209 else:
#
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#
#    6214 keyarr = self.take(indexer)
#
#    6215 if isinstance(key, Index):
#
#    6216     # GH 42790 - Preserve name from an Index
#
#
#
# File c:\Users\dev\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#
#    6259 if nmissing:
#
#    6260     if nmissing == len(indexer):
#
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
#    6264     raise KeyError(f"{not_found} not in index")
#
#
#
# KeyError: "None of [Index(['자격요건', '우대사항'], dtype='object')] are in the [index]"

# %%
fail_df.columns
# Out:
# Index(['회사', '제목', '경력', '근무형태', '학력', '근무지역', '링크', '지원 링크', '자격요건', '우대사항'], dtype='object')
